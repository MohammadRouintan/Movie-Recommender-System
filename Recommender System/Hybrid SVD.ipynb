# %%
import numpy as np
import pandas as pd
from surprise import Dataset, SVD
from sklearn.metrics.pairwise import linear_kernel, cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from surprise.model_selection import cross_validate , KFold

# %%
moviesData = pd.read_csv("../data/MoviesMetadata.csv")
moviesData.head(10)
# Out:
#    budget     id    imdb_id original_language               original_title  \
# 0    30.0    862  tt0114709                en                    Toy Story
# 1    65.0   8844  tt0113497                en                      Jumanji
# 2     0.0  15602  tt0113228                en             Grumpier Old Men
# 3    16.0  31357  tt0114885                en            Waiting to Exhale
# 4     0.0  11862  tt0113041                en  Father of the Bride Part II
# 5    60.0    949  tt0113277                en                         Heat
# 6    58.0  11860  tt0114319                en                      Sabrina
# 7     0.0  45325  tt0112302                en                 Tom and Huck
# 8    35.0   9091  tt0114576                en                 Sudden Death
# 9    58.0    710  tt0113189                en                    GoldenEye
#
#                                             overview  popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...   21.946943
# 1  When siblings Judy and Peter discover an encha...   17.015539
# 2  A family wedding reignites the ancient feud be...   11.712900
# 3  Cheated on, mistreated and stepped on, the wom...    3.859495
# 4  Just when George Banks has recovered from his ...    8.387519
# 5  Obsessive master thief, Neil McCauley leads a ...   17.924927
# 6  An ugly duckling having undergone a remarkable...    6.677277
# 7  A mischievous young boy, Tom Sawyer, witnesses...    2.561161
# 8  International action superstar Jean Claude Van...    5.231580
# 9  James Bond must unmask the mysterious head of ...   14.686036
#
#                         poster_path release_date     revenue  ...  \
# 0  /rhIRbceoE9lR4veEXuwCC2wARtG.jpg   1995-10-30  373.554033  ...
# 1  /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg   1995-12-15  262.797249  ...
# 2  /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg   1995-12-22    0.000000  ...
# 3  /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg   1995-12-22   81.452156  ...
# 4  /e64sOI48hQXyru7naBFyssKFxVd.jpg   1995-02-10   76.578911  ...
# 5  /zMyfPUelumio3tiDKPffaUpsQTD.jpg   1995-12-15  187.436818  ...
# 6  /jQh15y5YB7bWz1NtffNZmRw0s9D.jpg   1995-12-15    0.000000  ...
# 7  /sGO5Qa55p7wTu7FJcX4H4xIVKvS.jpg   1995-12-22    0.000000  ...
# 8  /eoWvKD60lT95Ss1MYNgVExpo5iU.jpg   1995-12-22   64.350171  ...
# 9  /5c0ovjT41KnYIHYuF4AWsTe3sKh.jpg   1995-11-16  352.194034  ...
#
#                          title vote_average vote_count  \
# 0                    Toy Story          7.7     5415.0
# 1                      Jumanji          6.9     2413.0
# 2             Grumpier Old Men          6.5       92.0
# 3            Waiting to Exhale          6.1       34.0
# 4  Father of the Bride Part II          5.7      173.0
# 5                         Heat          7.7     1886.0
# 6                      Sabrina          6.2      141.0
# 7                 Tom and Huck          5.4       45.0
# 8                 Sudden Death          5.5      174.0
# 9                    GoldenEye          6.6     1194.0
#
#                         name_genres          id_genres  \
# 0         Animation, Comedy, Family      16, 35, 10751
# 1        Adventure, Fantasy, Family      12, 14, 10751
# 2                   Romance, Comedy          10749, 35
# 3            Comedy, Drama, Romance      35, 18, 10749
# 4                            Comedy                 35
# 5    Action, Crime, Drama, Thriller     28, 80, 18, 53
# 6                   Comedy, Romance          35, 10749
# 7  Action, Adventure, Drama, Family  28, 12, 18, 10751
# 8       Action, Adventure, Thriller         28, 12, 53
# 9       Adventure, Action, Thriller         12, 28, 53
#
#                   name_production_countries iso_3166_1_production_countries  \
# 0                  United States of America                              US
# 1                  United States of America                              US
# 2                  United States of America                              US
# 3                  United States of America                              US
# 4                  United States of America                              US
# 5                  United States of America                              US
# 6         Germany, United States of America                          DE, US
# 7                  United States of America                              US
# 8                  United States of America                              US
# 9  United Kingdom, United States of America                          GB, US
#
#                            name_production_companies  \
# 0                            Pixar Animation Studios
# 1  TriStar Pictures, Teitler Film, Interscope Com...
# 2                       Warner Bros., Lancaster Gate
# 3             Twentieth Century Fox Film Corporation
# 4         Sandollar Productions, Touchstone Pictures
# 5    Regency Enterprises, Forward Pass, Warner Bros.
# 6  Paramount Pictures, Scott Rudin Productions, M...
# 7                               Walt Disney Pictures
# 8  Universal Pictures, Imperial Entertainment, Si...
# 9                    United Artists, Eon Productions
#
#                   id_production_companies  year
# 0                                       3  1995
# 1                        559, 2550, 10201  1995
# 2                             6194, 19464  1995
# 3                                     306  1995
# 4                              5842, 9195  1995
# 5                          508, 675, 6194  1995
# 6  4, 258, 932, 5842, 14941, 55873, 58079  1995
# 7                                       2  1995
# 8                        33, 21437, 23770  1995
# 9                                60, 7576  1995
#
# [10 rows x 23 columns]

# %%
reader = Reader()
ratings = pd.read_csv('../data/ratings_small.csv')
ratings
# Out:
#         userId  movieId  rating   timestamp
# 0            1       31     2.5  1260759144
# 1            1     1029     3.0  1260759179
# 2            1     1061     3.0  1260759182
# 3            1     1129     2.0  1260759185
# 4            1     1172     4.0  1260759205
# ...        ...      ...     ...         ...
# 99999      671     6268     2.5  1065579370
# 100000     671     6269     4.0  1065149201
# 100001     671     6365     4.0  1070940363
# 100002     671     6385     2.5  1070979663
# 100003     671     6565     3.5  1074784724
#
# [100004 rows x 4 columns]

# %%
data = Dataset.load_from_df(ratings[['userId', 'movieId', 'rating']], reader)
svd = SVD()
model_selection.validation.cross_validate(svd, data, measures=['RMSE', 'MAE'])
# Out:
# {'test_rmse': array([0.89894147, 0.89062879, 0.895646  , 0.90003445, 0.89885457]),
#  'test_mae': array([0.69290723, 0.68506534, 0.68776496, 0.68962671, 0.69314837]),
#  'fit_time': (0.5233252048492432,
#   0.558434009552002,
#   0.5117073059082031,
#   0.5261669158935547,
#   0.5414841175079346),
#  'test_time': (0.4097011089324951,
#   0.07498288154602051,
#   0.07412195205688477,
#   0.07337331771850586,
#   0.07826709747314453)}

# %%
data = Dataset.load_from_df(ratings[['userId', 'movieId', 'rating']], reader)
kf = KFold(n_splits=5)
kf.split(data) 
svd = SVD()
cross_validate(svd, data, measures=['RMSE', 'MAE'], cv=5, verbose=True)
trainset = data.build_full_trainset()
svd.fit(trainset)
# Out:
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.8946  0.8925  0.8922  0.8976  0.9014  0.8957  0.0035
# MAE (testset)     0.6906  0.6872  0.6883  0.6908  0.6917  0.6897  0.0017
# Fit time          0.70    0.67    0.56    0.53    0.56    0.60    0.07
# Test time         0.33    0.09    0.14    0.08    0.08    0.14    0.10

# %%
svd.predict(1 ,31 ,2.5)
# Out:
# Prediction(uid=1, iid=31, r_ui=2.5, est=2.462472868467107, details={'was_impossible': False})

# %%
ratings[ratings['userId'] == 1]
# Out:
#     userId  movieId  rating   timestamp
# 0        1       31     2.5  1260759144
# 1        1     1029     3.0  1260759179
# 2        1     1061     3.0  1260759182
# 3        1     1129     2.0  1260759185
# 4        1     1172     4.0  1260759205
# 5        1     1263     2.0  1260759151
# 6        1     1287     2.0  1260759187
# 7        1     1293     2.0  1260759148
# 8        1     1339     3.5  1260759125
# 9        1     1343     2.0  1260759131
# 10       1     1371     2.5  1260759135
# 11       1     1405     1.0  1260759203
# 12       1     1953     4.0  1260759191
# 13       1     2105     4.0  1260759139
# 14       1     2150     3.0  1260759194
# 15       1     2193     2.0  1260759198
# 16       1     2294     2.0  1260759108
# 17       1     2455     2.5  1260759113
# 18       1     2968     1.0  1260759200
# 19       1     3671     3.0  1260759117

# %%
links = pd.read_csv('../data/links.csv')
links = links.dropna()
links.isna().sum()
links['tmdbId'] = links['tmdbId'].astype('int64')
type(links['tmdbId'][0])
# Out:
# numpy.int64

# %%
links
# Out:
#       movieId   imdbId    tmdbId
# 0           1   114709     862.0
# 1           2   113497    8844.0
# 2           3   113228   15602.0
# 3           4   114885   31357.0
# 4           5   113041   11862.0
# ...       ...      ...       ...
# 9120   162672  3859980  402672.0
# 9121   163056  4262980  315011.0
# 9122   163949  2531318  391698.0
# 9123   164977    27660  137608.0
# 9124   164979  3447228  410803.0
#
# [9125 rows x 3 columns]

# %%
moviesData['tagline'] = moviesData['tagline'].fillna('')
moviesData['description'] = moviesData['overview'] + moviesData['tagline']
moviesData['description'] = moviesData['description'].fillna('')

# %%
tf = TfidfVectorizer(analyzer='word',ngram_range=(1, 2),min_df=0, stop_words='english')
tfidf_matrix = tf.fit_transform(moviesData['description'])

# %%
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
indices = pd.Series(moviesData.index, index=moviesData['title'])

# %%
indices["Three Colors: Red"]
# Out:
# 302

# %%
def hybrid(userId, title):
    idx = indices[title]
    try:
        sim_scores = list(enumerate(cosine_sim[int(idx[0])]))
    except:
        sim_scores = list(enumerate(cosine_sim[int(idx)]))

    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:26]
    movie_indices = [i[0] for i in sim_scores]
    
    movies = moviesData.iloc[movie_indices][['title', 'vote_count', 'vote_average', 'year', 'id']]
    
    tempLinks = links[links['tmdbId'].isin(movies['id'].tolist())]  
    
    l = list() 
    
    for item in  tempLinks["movieId"]:
        temp = svd.predict(userId, item).est
        if temp >= 4.0:
            l.append (temp)
    
    tempData = pd.DataFrame({"title" :movies['title'],"est": l ,"vote_count" :movies['vote_count'] ,"vote_average" :movies['vote_average'] ,"year" :movies['year'] ,"id" :movies['id']})

    
    tempData = tempData.sort_values('est', ascending=False)

    
    return tempData.head(3)

# %%
hybrid(1, 'The Poseidon Adventure')
# Out:
#                                        title       est  vote_count  \
# 29357                           Final Voyage  2.697262         4.0
# 39111                                 Andron  2.670098        49.0
# 37635                             This Night  2.670098         4.0
# 44565                           Wounded Game  2.670098         4.0
# 42842                             The Raking  2.670098         6.0
# 41619  1898. Our Last Men in the Philippines  2.670098        39.0
# 23105            Do You Wanna Know a Secret?  2.670098         2.0
# 24953          Rent: Filmed Live on Broadway  2.670098        11.0
# 15393                          Little Dorrit  2.670098         1.0
# 3446                              The Idiots  2.670098       107.0
#
#        vote_average  year      id
# 29357           3.5  2000   95493
# 39111           3.9  2015  395883
# 37635           7.0  2008   12422
# 44565           6.8  1977   48882
# 42842           5.7  2017  445602
# 41619           6.5  2016  403357
# 23105           4.0  2001  117905
# 24953           7.0  2008   15199
# 15393          10.0  1987   47282
# 3446            6.7  1998     452

# %%
def getUserRecommender(userID):
    tempRatings = ratings[ratings['userId'] == userID]
    
    tempRatings =  tempRatings[tempRatings["rating"] >= 4]
    
    tempLinks = links[links['tmdbId'].isin(tempRatings['movieId'].tolist())]  
    
    titlesData = moviesData[moviesData["id"].isin(tempLinks["tmdbId"])]
    
    resultDataFrame = pd.DataFrame()
        
    for title in titlesData["title"]:
        resultDataFrame = pd.concat([hybrid(userID,title), resultDataFrame], ignore_index = True)
        
    
    
    return resultDataFrame.sort_values('est', ascending=False)

# %%
getUserRecommender(600)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 getUserRecommender(600)
#
# NameError: name 'getUserRecommender' is not defined

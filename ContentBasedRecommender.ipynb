# %% [markdown]
# ## Content Based Recommender

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
movies = pd.read_csv('data/MoviesMetadata.csv')
movies.head()
# Out:
#    budget     id    imdb_id original_language               original_title  \
# 0    30.0    862  tt0114709                en                    Toy Story
# 1    65.0   8844  tt0113497                en                      Jumanji
# 2     0.0  15602  tt0113228                en             Grumpier Old Men
# 3    16.0  31357  tt0114885                en            Waiting to Exhale
# 4     0.0  11862  tt0113041                en  Father of the Bride Part II
#
#                                             overview  popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...   21.946943
# 1  When siblings Judy and Peter discover an encha...   17.015539
# 2  A family wedding reignites the ancient feud be...   11.712900
# 3  Cheated on, mistreated and stepped on, the wom...    3.859495
# 4  Just when George Banks has recovered from his ...    8.387519
#
#                         poster_path release_date     revenue  ...  \
# 0  /rhIRbceoE9lR4veEXuwCC2wARtG.jpg   1995-10-30  373.554033  ...
# 1  /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg   1995-12-15  262.797249  ...
# 2  /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg   1995-12-22    0.000000  ...
# 3  /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg   1995-12-22   81.452156  ...
# 4  /e64sOI48hQXyru7naBFyssKFxVd.jpg   1995-02-10   76.578911  ...
#
#                          title vote_average vote_count  \
# 0                    Toy Story          7.7     5415.0
# 1                      Jumanji          6.9     2413.0
# 2             Grumpier Old Men          6.5       92.0
# 3            Waiting to Exhale          6.1       34.0
# 4  Father of the Bride Part II          5.7      173.0
#
#                   name_genres      id_genres  name_production_countries  \
# 0   Animation, Comedy, Family  16, 35, 10751   United States of America
# 1  Adventure, Fantasy, Family  12, 14, 10751   United States of America
# 2             Romance, Comedy      10749, 35   United States of America
# 3      Comedy, Drama, Romance  35, 18, 10749   United States of America
# 4                      Comedy             35   United States of America
#
#   iso_3166_1_production_countries  \
# 0                              US
# 1                              US
# 2                              US
# 3                              US
# 4                              US
#
#                            name_production_companies id_production_companies  \
# 0                            Pixar Animation Studios                       3
# 1  TriStar Pictures, Teitler Film, Interscope Com...        559, 2550, 10201
# 2                       Warner Bros., Lancaster Gate             6194, 19464
# 3             Twentieth Century Fox Film Corporation                     306
# 4         Sandollar Productions, Touchstone Pictures              5842, 9195
#
#    year
# 0  1995
# 1  1995
# 2  1995
# 3  1995
# 4  1995
#
# [5 rows x 23 columns]

# %%
movies.columns
# Out:
# Index(['budget', 'id', 'imdb_id', 'original_language', 'original_title',
#        'overview', 'popularity', 'poster_path', 'release_date', 'revenue',
#        'runtime', 'status', 'tagline', 'title', 'vote_average', 'vote_count',
#        'name_genres', 'id_genres', 'name_production_countries',
#        'iso_3166_1_production_countries', 'name_production_companies',
#        'id_production_companies', 'year'],
#       dtype='object')

# %%
movies.drop(columns=['iso_3166_1_production_countries', 'id_production_companies', 'id_genres'], inplace=True)
movies.shape
# Out:
# (45443, 20)

# %%
links = pd.read_csv('data/links.csv')
links = links[links['tmdbId'].notnull()]['tmdbId'].astype('int')

# %%
links.head()
# Out:
# 0      862
# 1     8844
# 2    15602
# 3    31357
# 4    11862
# Name: tmdbId, dtype: int64

# %%
movies_meta = movies[movies['id'].isin(links)]
movies_meta.shape
# Out:
# (45443, 20)

# %%
movies_meta['description'] = movies_meta['overview'] + movies_meta['tagline']
movies_meta['description'] = movies_meta['description'].fillna('')

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
tf = TfidfVectorizer(analyzer='word', ngram_range=(1, 2), min_df=0, stop_words='english')
tfidf_matrix = tf.fit_transform(movies_meta['description'])

# %%
from sklearn.metrics.pairwise import linear_kernel
cosine_similarity = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
movies_meta = movies_meta.reset_index()
titles = movies_meta['title']
indices = pd.Series(movies_meta.index, index=movies_meta['title'])

# %%
indices.shape
# Out:
# (45443,)

# %%
def find_idx(title):
    idx = pd.Series(indices[title])
    return idx[0]

# %%
def get_recommendations(title):
    idx = find_idx(title=title)
    similarity_scores = list(enumerate(cosine_similarity[idx]))
    similarity_scores = sorted(similarity_scores, key=lambda x: x[1], reverse=True)
    similarity_scores = similarity_scores[1:21]
    movie_indices = [i[0] for i in similarity_scores]
    return titles.iloc[movie_indices]

# %%
get_recommendations('The Dark Knight').head(20)
# Out:
# 18247                      The Dark Knight Rises
# 150                               Batman Forever
# 1328                              Batman Returns
# 585                                       Batman
# 15507                 Batman: Under the Red Hood
# 20225    Batman: The Dark Knight Returns, Part 2
# 41954                      The Lego Batman Movie
# 18030                           Batman: Year One
# 25255                          Batman vs Dracula
# 9228          Batman Beyond: Return of the Joker
# 22012                             The Super Cops
# 11750                                  Slow Burn
# 3094                Batman: Mask of the Phantasm
# 3266                                         JFK
# 32103           Batman Unlimited: Monster Mayhem
# 19785    Batman: The Dark Knight Returns, Part 1
# 39606                   Batman: The Killing Joke
# 13928                                 Judas Kiss
# 18253         Sherlock Holmes: A Game of Shadows
# 7672                                 Masterminds
# Name: title, dtype: object

# %%
get_recommendations('Harry Potter and the Philosopher\'s Stone').head(20)
# Out:
# 23495                                             Luv
# 5677          Harry Potter and the Chamber of Secrets
# 22006                              The Starving Games
# 4369                                    The Dead Pool
# 7724         Harry Potter and the Prisoner of Azkaban
# 10551             Harry Potter and the Goblet of Fire
# 18616                           A Very Potter Musical
# 39045                               Bullet to Beijing
# 3950                         Harry, He's Here To Help
# 7114                                    Love at Large
# 11924       Harry Potter and the Order of the Phoenix
# 30551                                            1920
# 39672                               Bridge and Tunnel
# 3583                                      Angel Heart
# 16124    Harry Potter and the Deathly Hallows: Part 1
# 18820                                Wild About Harry
# 17432    Harry Potter and the Deathly Hallows: Part 2
# 1596                                        Incognito
# 4979                                     The Good Son
# 3269                                  Let's Get Harry
# Name: title, dtype: object

# %%
get_recommendations('Carrington')
# Out:
# 21374              Alan Partridge: Alpha Papa
# 6733                                   Sylvia
# 40394                           Hacksaw Ridge
# 493                                 Mr. Jones
# 21750           Muhammad Ali's Greatest Fight
# 12266                           Close My Eyes
# 43873                            Giving It Up
# 32811                     The Lady in the Van
# 22201                          Geography Club
# 22820    The Cutting Edge: Going for the Gold
# 14014               Just Sex and Nothing Else
# 5970                       One from the Heart
# 21508         Family Band: The Cowsills Story
# 13684                     The Merry Gentleman
# 41997                                 Rangoon
# 34184                              Blind Date
# 6388                            Swimming Pool
# 10782                        Imagine Me & You
# 41062                        The Constitution
# 1852                       Driving Miss Daisy
# Name: title, dtype: object

# %%
# %pip install recmetrics
# Out:
# Collecting recmetrics
#   Using cached recmetrics-0.1.5-py3-none-any.whl (9.3 kB)
# Collecting funcsigs<2.0.0,>=1.0.2 (from recmetrics)
#   Using cached funcsigs-1.0.2-py2.py3-none-any.whl (17 kB)
# Collecting ipython<8.0.0,>=7.18.1 (from recmetrics)
#   Using cached ipython-7.34.0-py3-none-any.whl (793 kB)
# Collecting jupyter<2.0.0,>=1.0.0 (from recmetrics)
#   Using cached jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Requirement already satisfied: matplotlib<4.0.0,>=3.3.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from recmetrics) (3.7.0)
# Requirement already satisfied: pandas<2.0.0,>=1.1.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from recmetrics) (1.5.3)
# Collecting plotly<5.0.0,>=4.11.0 (from recmetrics)
#   Downloading plotly-4.14.3-py2.py3-none-any.whl (13.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 106.9 kB/s eta 0:00:0000:0100:04
# Collecting pytest-cov<3.0.0,>=2.10.1 (from recmetrics)
#   Downloading pytest_cov-2.12.1-py2.py3-none-any.whl (20 kB)
# Requirement already satisfied: scikit-learn<2.0.0,>=1.0.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from recmetrics) (1.2.2)
# Requirement already satisfied: scipy<2.0.0,>=1.5.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from recmetrics) (1.10.1)
# Collecting seaborn<0.12.0,>=0.11.0 (from recmetrics)
#   Using cached seaborn-0.11.2-py3-none-any.whl (292 kB)
# Collecting twine<5.0.0,>=4.0.0 (from recmetrics)
#   Downloading twine-4.0.2-py3-none-any.whl (36 kB)
# Requirement already satisfied: setuptools>=18.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ipython<8.0.0,>=7.18.1->recmetrics) (65.5.0)
# Requirement already satisfied: jedi>=0.16 in /Users/mohammad/Library/Python/3.11/lib/python/site-packages (from ipython<8.0.0,>=7.18.1->recmetrics) (0.18.2)
# Requirement already satisfied: decorator in /Users/mohammad/Library/Python/3.11/lib/python/site-packages (from ipython<8.0.0,>=7.18.1->recmetrics) (5.1.1)
# Requirement already satisfied: pickleshare in /Users/mohammad/Library/Python/3.11/lib/python/site-packages (from ipython<8.0.0,>=7.18.1->recmetrics) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /Users/mohammad/Library/Python/3.11/lib/python/site-packages (from ipython<8.0.0,>=7.18.1->recmetrics) (5.9.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/mohammad/Library/Python/3.11/lib/python/site-packages (from ipython<8.0.0,>=7.18.1->recmetrics) (3.0.38)
# Requirement already satisfied: pygments in /Users/mohammad/Library/Python/3.11/lib/python/site-packages (from ipython<8.0.0,>=7.18.1->recmetrics) (2.14.0)
# Requirement already satisfied: backcall in /Users/mohammad/Library/Python/3.11/lib/python/site-packages (from ipython<8.0.0,>=7.18.1->recmetrics) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /Users/mohammad/Library/Python/3.11/lib/python/site-packages (from ipython<8.0.0,>=7.18.1->recmetrics) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /Users/mohammad/Library/Python/3.11/lib/python/site-packages (from ipython<8.0.0,>=7.18.1->recmetrics) (4.8.0)
# Requirement already satisfied: appnope in /Users/mohammad/Library/Python/3.11/lib/python/site-packages (from ipython<8.0.0,>=7.18.1->recmetrics) (0.1.3)
# Collecting notebook (from jupyter<2.0.0,>=1.0.0->recmetrics)
#   Downloading notebook-6.5.4-py3-none-any.whl (529 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 529.8/529.8 kB 227.5 kB/s eta 0:00:00a 0:00:01
# Collecting qtconsole (from jupyter<2.0.0,>=1.0.0->recmetrics)
#   Downloading qtconsole-5.4.3-py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.9/121.9 kB 178.8 kB/s eta 0:00:00a 0:00:01
# Collecting jupyter-console (from jupyter<2.0.0,>=1.0.0->recmetrics)
#   Downloading jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Collecting nbconvert (from jupyter<2.0.0,>=1.0.0->recmetrics)
#   Downloading nbconvert-7.6.0-py3-none-any.whl (290 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.4/290.4 kB 116.5 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: ipykernel in /Users/mohammad/Library/Python/3.11/lib/python/site-packages (from jupyter<2.0.0,>=1.0.0->recmetrics) (6.21.2)
# Collecting ipywidgets (from jupyter<2.0.0,>=1.0.0->recmetrics)
#   Downloading ipywidgets-8.0.6-py3-none-any.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.3/138.3 kB 144.2 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib<4.0.0,>=3.3.2->recmetrics) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib<4.0.0,>=3.3.2->recmetrics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib<4.0.0,>=3.3.2->recmetrics) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib<4.0.0,>=3.3.2->recmetrics) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib<4.0.0,>=3.3.2->recmetrics) (1.24.2)
# Requirement already satisfied: packaging>=20.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib<4.0.0,>=3.3.2->recmetrics) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib<4.0.0,>=3.3.2->recmetrics) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib<4.0.0,>=3.3.2->recmetrics) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib<4.0.0,>=3.3.2->recmetrics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas<2.0.0,>=1.1.3->recmetrics) (2022.7.1)
# Collecting retrying>=1.3.3 (from plotly<5.0.0,>=4.11.0->recmetrics)
#   Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Requirement already satisfied: six in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from plotly<5.0.0,>=4.11.0->recmetrics) (1.16.0)
# Collecting pytest>=4.6 (from pytest-cov<3.0.0,>=2.10.1->recmetrics)
#   Downloading pytest-7.4.0-py3-none-any.whl (323 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.6/323.6 kB 116.3 kB/s eta 0:00:00a 0:00:01
# Collecting coverage>=5.2.1 (from pytest-cov<3.0.0,>=2.10.1->recmetrics)
#   Downloading coverage-7.2.7-cp311-cp311-macosx_11_0_arm64.whl (201 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.1/201.1 kB 127.9 kB/s eta 0:00:00a 0:00:01
# Collecting toml (from pytest-cov<3.0.0,>=2.10.1->recmetrics)
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: joblib>=1.1.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from scikit-learn<2.0.0,>=1.0.2->recmetrics) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from scikit-learn<2.0.0,>=1.0.2->recmetrics) (3.1.0)
# Collecting pkginfo>=1.8.1 (from twine<5.0.0,>=4.0.0->recmetrics)
#   Downloading pkginfo-1.9.6-py3-none-any.whl (30 kB)
# Collecting readme-renderer>=35.0 (from twine<5.0.0,>=4.0.0->recmetrics)
#   Downloading readme_renderer-40.0-py3-none-any.whl (14 kB)
# Collecting requests>=2.20 (from twine<5.0.0,>=4.0.0->recmetrics)
#   Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 100.6 kB/s eta 0:00:00a 0:00:01
# Collecting requests-toolbelt!=0.9.0,>=0.8.0 (from twine<5.0.0,>=4.0.0->recmetrics)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 100.2 kB/s eta 0:00:00a 0:00:01
# Collecting urllib3>=1.26.0 (from twine<5.0.0,>=4.0.0->recmetrics)
#   Downloading urllib3-2.0.3-py3-none-any.whl (123 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.6/123.6 kB 111.1 kB/s eta 0:00:00a 0:00:01
# Collecting importlib-metadata>=3.6 (from twine<5.0.0,>=4.0.0->recmetrics)
#   Downloading importlib_metadata-6.7.0-py3-none-any.whl (22 kB)
# Collecting keyring>=15.1 (from twine<5.0.0,>=4.0.0->recmetrics)
#   Downloading keyring-24.2.0-py3-none-any.whl (37 kB)
# Collecting rfc3986>=1.4.0 (from twine<5.0.0,>=4.0.0->recmetrics)
#   Downloading rfc3986-2.0.0-py2.py3-none-any.whl (31 kB)
# Collecting rich>=12.0.0 (from twine<5.0.0,>=4.0.0->recmetrics)
#   Downloading rich-13.4.2-py3-none-any.whl (239 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.4/239.4 kB 130.0 kB/s eta 0:00:0000:0100:01
# Collecting zipp>=0.5 (from importlib-metadata>=3.6->twine<5.0.0,>=4.0.0->recmetrics)
#   Using cached zipp-3.15.0-py3-none-any.whl (6.8 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/mohammad/Library/Python/3.11/lib/python/site-packages (from jedi>=0.16->ipython<8.0.0,>=7.18.1->recmetrics) (0.8.3)
# Collecting jaraco.classes (from keyring>=15.1->twine<5.0.0,>=4.0.0->recmetrics)
#   Downloading jaraco.classes-3.2.3-py3-none-any.whl (6.0 kB)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/mohammad/Library/Python/3.11/lib/python/site-packages (from pexpect>4.3->ipython<8.0.0,>=7.18.1->recmetrics) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/mohammad/Library/Python/3.11/lib/python/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<8.0.0,>=7.18.1->recmetrics) (0.2.6)
# Collecting iniconfig (from pytest>=4.6->pytest-cov<3.0.0,>=2.10.1->recmetrics)
#   Downloading iniconfig-2.0.0-py3-none-any.whl (5.9 kB)
# Collecting pluggy<2.0,>=0.12 (from pytest>=4.6->pytest-cov<3.0.0,>=2.10.1->recmetrics)
#   Downloading pluggy-1.2.0-py3-none-any.whl (17 kB)
# Collecting bleach>=2.1.0 (from readme-renderer>=35.0->twine<5.0.0,>=4.0.0->recmetrics)
#   Using cached bleach-6.0.0-py3-none-any.whl (162 kB)
# Collecting docutils>=0.13.1 (from readme-renderer>=35.0->twine<5.0.0,>=4.0.0->recmetrics)
#   Downloading docutils-0.20.1-py3-none-any.whl (572 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 572.7/572.7 kB 110.6 kB/s eta 0:00:0000:0100:01
# Collecting charset-normalizer<4,>=2 (from requests>=2.20->twine<5.0.0,>=4.0.0->recmetrics)
#   Downloading charset_normalizer-3.1.0-cp311-cp311-macosx_11_0_arm64.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.7/121.7 kB 124.7 kB/s eta 0:00:00a 0:00:01
# Collecting idna<4,>=2.5 (from requests>=2.20->twine<5.0.0,>=4.0.0->recmetrics)
#   Using cached idna-3.4-py3-none-any.whl (61 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.20->twine<5.0.0,>=4.0.0->recmetrics)
#   Downloading certifi-2023.5.7-py3-none-any.whl (156 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.0/157.0 kB 108.6 kB/s eta 0:00:00a 0:00:01
# Collecting markdown-it-py>=2.2.0 (from rich>=12.0.0->twine<5.0.0,>=4.0.0->recmetrics)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 128.9 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: comm>=0.1.1 in /Users/mohammad/Library/Python/3.11/lib/python/site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->recmetrics) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/mohammad/Library/Python/3.11/lib/python/site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->recmetrics) (1.6.6)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/mohammad/Library/Python/3.11/lib/python/site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->recmetrics) (8.0.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/mohammad/Library/Python/3.11/lib/python/site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->recmetrics) (5.2.0)
# Requirement already satisfied: nest-asyncio in /Users/mohammad/Library/Python/3.11/lib/python/site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->recmetrics) (1.5.6)
# Requirement already satisfied: psutil in /Users/mohammad/Library/Python/3.11/lib/python/site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->recmetrics) (5.9.4)
# Requirement already satisfied: pyzmq>=20 in /Users/mohammad/Library/Python/3.11/lib/python/site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->recmetrics) (25.0.0)
# Requirement already satisfied: tornado>=6.1 in /Users/mohammad/Library/Python/3.11/lib/python/site-packages (from ipykernel->jupyter<2.0.0,>=1.0.0->recmetrics) (6.2)
# Collecting widgetsnbextension~=4.0.7 (from ipywidgets->jupyter<2.0.0,>=1.0.0->recmetrics)
#   Downloading widgetsnbextension-4.0.7-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 91.2 kB/s eta 0:00:0000:0100:01m
# Collecting jupyterlab-widgets~=3.0.7 (from ipywidgets->jupyter<2.0.0,>=1.0.0->recmetrics)
#   Downloading jupyterlab_widgets-3.0.7-py3-none-any.whl (198 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 198.2/198.2 kB 335.0 kB/s eta 0:00:0000:0100:01
# Collecting beautifulsoup4 (from nbconvert->jupyter<2.0.0,>=1.0.0->recmetrics)
#   Downloading beautifulsoup4-4.12.2-py3-none-any.whl (142 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.0/143.0 kB 420.9 kB/s eta 0:00:00a 0:00:01
# Collecting defusedxml (from nbconvert->jupyter<2.0.0,>=1.0.0->recmetrics)
#   Using cached defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Collecting jinja2>=3.0 (from nbconvert->jupyter<2.0.0,>=1.0.0->recmetrics)
#   Using cached Jinja2-3.1.2-py3-none-any.whl (133 kB)
# Collecting jupyterlab-pygments (from nbconvert->jupyter<2.0.0,>=1.0.0->recmetrics)
#   Using cached jupyterlab_pygments-0.2.2-py2.py3-none-any.whl (21 kB)
# Collecting markupsafe>=2.0 (from nbconvert->jupyter<2.0.0,>=1.0.0->recmetrics)
#   Downloading MarkupSafe-2.1.3-cp311-cp311-macosx_10_9_universal2.whl (17 kB)
# Collecting mistune<4,>=2.0.3 (from nbconvert->jupyter<2.0.0,>=1.0.0->recmetrics)
#   Downloading mistune-3.0.1-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.0/48.0 kB 600.1 kB/s eta 0:00:00a 0:00:01
# Collecting nbclient>=0.5.0 (from nbconvert->jupyter<2.0.0,>=1.0.0->recmetrics)
#   Downloading nbclient-0.8.0-py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 2.7 MB/s eta 0:00:00
# Collecting nbformat>=5.7 (from nbconvert->jupyter<2.0.0,>=1.0.0->recmetrics)
#   Using cached nbformat-5.9.0-py3-none-any.whl (77 kB)
# Collecting pandocfilters>=1.4.1 (from nbconvert->jupyter<2.0.0,>=1.0.0->recmetrics)
#   Using cached pandocfilters-1.5.0-py2.py3-none-any.whl (8.7 kB)
# Collecting tinycss2 (from nbconvert->jupyter<2.0.0,>=1.0.0->recmetrics)
#   Using cached tinycss2-1.2.1-py3-none-any.whl (21 kB)
# Collecting argon2-cffi (from notebook->jupyter<2.0.0,>=1.0.0->recmetrics)
#   Using cached argon2_cffi-21.3.0-py3-none-any.whl (14 kB)
# Collecting ipython-genutils (from notebook->jupyter<2.0.0,>=1.0.0->recmetrics)
#   Using cached ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Collecting Send2Trash>=1.8.0 (from notebook->jupyter<2.0.0,>=1.0.0->recmetrics)
#   Downloading Send2Trash-1.8.2-py3-none-any.whl (18 kB)
# Collecting terminado>=0.8.3 (from notebook->jupyter<2.0.0,>=1.0.0->recmetrics)
#   Using cached terminado-0.17.1-py3-none-any.whl (17 kB)
# Collecting prometheus-client (from notebook->jupyter<2.0.0,>=1.0.0->recmetrics)
#   Downloading prometheus_client-0.17.0-py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 1.4 MB/s eta 0:00:00
# Collecting nbclassic>=0.4.7 (from notebook->jupyter<2.0.0,>=1.0.0->recmetrics)
#   Downloading nbclassic-1.0.0-py3-none-any.whl (10.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 94.2 kB/s eta 0:00:0000:010:03m
# Collecting qtpy>=2.0.1 (from qtconsole->jupyter<2.0.0,>=1.0.0->recmetrics)
#   Downloading QtPy-2.3.1-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.9/84.9 kB 100.0 kB/s eta 0:00:00a 0:00:01
# Collecting webencodings (from bleach>=2.1.0->readme-renderer>=35.0->twine<5.0.0,>=4.0.0->recmetrics)
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: platformdirs>=2.5 in /Users/mohammad/Library/Python/3.11/lib/python/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter<2.0.0,>=1.0.0->recmetrics) (3.0.0)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=12.0.0->twine<5.0.0,>=4.0.0->recmetrics)
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Collecting jupyter-server>=1.8 (from nbclassic>=0.4.7->notebook->jupyter<2.0.0,>=1.0.0->recmetrics)
#   Downloading jupyter_server-2.7.0-py3-none-any.whl (375 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 375.1/375.1 kB 99.6 kB/s eta 0:00:00a 0:00:01
# Collecting notebook-shim>=0.2.3 (from nbclassic>=0.4.7->notebook->jupyter<2.0.0,>=1.0.0->recmetrics)
#   Downloading notebook_shim-0.2.3-py3-none-any.whl (13 kB)
# Collecting fastjsonschema (from nbformat>=5.7->nbconvert->jupyter<2.0.0,>=1.0.0->recmetrics)
#   Using cached fastjsonschema-2.17.1-py3-none-any.whl (23 kB)
# Collecting jsonschema>=2.6 (from nbformat>=5.7->nbconvert->jupyter<2.0.0,>=1.0.0->recmetrics)
#   Using cached jsonschema-4.17.3-py3-none-any.whl (90 kB)
# Collecting argon2-cffi-bindings (from argon2-cffi->notebook->jupyter<2.0.0,>=1.0.0->recmetrics)
#   Using cached argon2_cffi_bindings-21.2.0-cp38-abi3-macosx_10_9_universal2.whl (53 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4->nbconvert->jupyter<2.0.0,>=1.0.0->recmetrics)
#   Downloading soupsieve-2.4.1-py3-none-any.whl (36 kB)
# Collecting more-itertools (from jaraco.classes->keyring>=15.1->twine<5.0.0,>=4.0.0->recmetrics)
#   Downloading more_itertools-9.1.0-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.2/54.2 kB 55.8 kB/s eta 0:00:00a 0:00:01
# Collecting attrs>=17.4.0 (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter<2.0.0,>=1.0.0->recmetrics)
#   Using cached attrs-23.1.0-py3-none-any.whl (61 kB)
# Collecting pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter<2.0.0,>=1.0.0->recmetrics)
#   Using cached pyrsistent-0.19.3-cp311-cp311-macosx_10_9_universal2.whl (82 kB)
# Collecting anyio>=3.1.0 (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter<2.0.0,>=1.0.0->recmetrics)
#   Downloading anyio-3.7.0-py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 kB 131.7 kB/s eta 0:00:00a 0:00:01
# Collecting jupyter-events>=0.6.0 (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter<2.0.0,>=1.0.0->recmetrics)
#   Using cached jupyter_events-0.6.3-py3-none-any.whl (18 kB)
# Collecting jupyter-server-terminals (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter<2.0.0,>=1.0.0->recmetrics)
#   Using cached jupyter_server_terminals-0.4.4-py3-none-any.whl (13 kB)
# Collecting overrides (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter<2.0.0,>=1.0.0->recmetrics)
#   Downloading overrides-7.3.1-py3-none-any.whl (17 kB)
# Collecting websocket-client (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter<2.0.0,>=1.0.0->recmetrics)
#   Downloading websocket_client-1.6.1-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 kB 146.6 kB/s eta 0:00:00a 0:00:01
# Collecting cffi>=1.0.1 (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter<2.0.0,>=1.0.0->recmetrics)
#   Downloading cffi-1.15.1-cp311-cp311-macosx_11_0_arm64.whl (174 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.2/174.2 kB 75.6 kB/s eta 0:00:00a 0:00:01
# Collecting sniffio>=1.1 (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter<2.0.0,>=1.0.0->recmetrics)
#   Using cached sniffio-1.3.0-py3-none-any.whl (10 kB)
# Collecting pycparser (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter<2.0.0,>=1.0.0->recmetrics)
#   Using cached pycparser-2.21-py2.py3-none-any.whl (118 kB)
# Collecting python-json-logger>=2.0.4 (from jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter<2.0.0,>=1.0.0->recmetrics)
#   Downloading python_json_logger-2.0.7-py3-none-any.whl (8.1 kB)
# Collecting pyyaml>=5.3 (from jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter<2.0.0,>=1.0.0->recmetrics)
#   Downloading PyYAML-6.0-cp311-cp311-macosx_11_0_arm64.whl (167 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.5/167.5 kB 99.9 kB/s eta 0:00:0000:0100:01
# Collecting rfc3339-validator (from jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter<2.0.0,>=1.0.0->recmetrics)
#   Using cached rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Collecting rfc3986-validator>=0.1.1 (from jupyter-events>=0.6.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter<2.0.0,>=1.0.0->recmetrics)
#   Using cached rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Collecting fqdn (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter<2.0.0,>=1.0.0->recmetrics)
#   Using cached fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Collecting isoduration (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter<2.0.0,>=1.0.0->recmetrics)
#   Using cached isoduration-20.11.0-py3-none-any.whl (11 kB)
# Collecting jsonpointer>1.13 (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter<2.0.0,>=1.0.0->recmetrics)
#   Downloading jsonpointer-2.4-py2.py3-none-any.whl (7.8 kB)
# Collecting uri-template (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter<2.0.0,>=1.0.0->recmetrics)
#   Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Collecting webcolors>=1.11 (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter<2.0.0,>=1.0.0->recmetrics)
#   Downloading webcolors-1.13-py3-none-any.whl (14 kB)
# Collecting arrow>=0.15.0 (from isoduration->jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter<2.0.0,>=1.0.0->recmetrics)
#   Using cached arrow-1.2.3-py3-none-any.whl (66 kB)
# Installing collected packages: webencodings, ipython-genutils, funcsigs, fastjsonschema, zipp, widgetsnbextension, websocket-client, webcolors, urllib3, uri-template, toml, tinycss2, terminado, soupsieve, sniffio, Send2Trash, rfc3986-validator, rfc3986, rfc3339-validator, retrying, qtpy, pyyaml, python-json-logger, pyrsistent, pycparser, prometheus-client, pluggy, pkginfo, pandocfilters, overrides, more-itertools, mistune, mdurl, markupsafe, jupyterlab-widgets, jupyterlab-pygments, jsonpointer, iniconfig, idna, fqdn, docutils, defusedxml, coverage, charset-normalizer, certifi, bleach, attrs, requests, readme-renderer, pytest, plotly, markdown-it-py, jupyter-server-terminals, jsonschema, jinja2, jaraco.classes, ipython, importlib-metadata, cffi, beautifulsoup4, arrow, anyio, seaborn, rich, requests-toolbelt, pytest-cov, nbformat, keyring, isoduration, argon2-cffi-bindings, twine, qtconsole, nbclient, jupyter-console, ipywidgets, argon2-cffi, nbconvert, jupyter-events, jupyter-server, notebook-shim, nbclassic, notebook, jupyter, recmetrics
#   Attempting uninstall: ipython
#     Found existing installation: ipython 8.11.0
#     Uninstalling ipython-8.11.0:
#       Successfully uninstalled ipython-8.11.0
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.12.2
#     Uninstalling seaborn-0.12.2:
#       Successfully uninstalled seaborn-0.12.2
# Successfully installed Send2Trash-1.8.2 anyio-3.7.0 argon2-cffi-21.3.0 argon2-cffi-bindings-21.2.0 arrow-1.2.3 attrs-23.1.0 beautifulsoup4-4.12.2 bleach-6.0.0 certifi-2023.5.7 cffi-1.15.1 charset-normalizer-3.1.0 coverage-7.2.7 defusedxml-0.7.1 docutils-0.20.1 fastjsonschema-2.17.1 fqdn-1.5.1 funcsigs-1.0.2 idna-3.4 importlib-metadata-6.7.0 iniconfig-2.0.0 ipython-7.34.0 ipython-genutils-0.2.0 ipywidgets-8.0.6 isoduration-20.11.0 jaraco.classes-3.2.3 jinja2-3.1.2 jsonpointer-2.4 jsonschema-4.17.3 jupyter-1.0.0 jupyter-console-6.6.3 jupyter-events-0.6.3 jupyter-server-2.7.0 jupyter-server-terminals-0.4.4 jupyterlab-pygments-0.2.2 jupyterlab-widgets-3.0.7 keyring-24.2.0 markdown-it-py-3.0.0 markupsafe-2.1.3 mdurl-0.1.2 mistune-3.0.1 more-itertools-9.1.0 nbclassic-1.0.0 nbclient-0.8.0 nbconvert-7.6.0 nbformat-5.9.0 notebook-6.5.4 notebook-shim-0.2.3 overrides-7.3.1 pandocfilters-1.5.0 pkginfo-1.9.6 plotly-4.14.3 pluggy-1.2.0 prometheus-client-0.17.0 pycparser-2.21 pyrsistent-0.19.3 pytest-7.4.0 pytest-cov-2.12.1 python-json-logger-2.0.7 pyyaml-6.0 qtconsole-5.4.3 qtpy-2.3.1 readme-renderer-40.0 recmetrics-0.1.5 requests-2.31.0 requests-toolbelt-1.0.0 retrying-1.3.4 rfc3339-validator-0.1.4 rfc3986-2.0.0 rfc3986-validator-0.1.1 rich-13.4.2 seaborn-0.11.2 sniffio-1.3.0 soupsieve-2.4.1 terminado-0.17.1 tinycss2-1.2.1 toml-0.10.2 twine-4.0.2 uri-template-1.3.0 urllib3-2.0.3 webcolors-1.13 webencodings-0.5.1 websocket-client-1.6.1 widgetsnbextension-4.0.7 zipp-3.15.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import recmetrics

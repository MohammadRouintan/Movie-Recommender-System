# %% [markdown]
# ## Movie Metadata EDA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
movies = pd.read_csv('../data/NewMoviesMetadata.csv')
movies.head()
# Out:
#    adult    budget                              homepage     id    imdb_id  \
# 0  False  30000000  http://toystory.disney.com/toy-story    862  tt0114709
# 1  False  65000000                                  NANE   8844  tt0113497
# 2  False         0                                  NANE  15602  tt0113228
# 3  False  16000000                                  NANE  31357  tt0114885
# 4  False         0                                  NANE  11862  tt0113041
#
#   original_language               original_title  \
# 0                en                    Toy Story
# 1                en                      Jumanji
# 2                en             Grumpier Old Men
# 3                en            Waiting to Exhale
# 4                en  Father of the Bride Part II
#
#                                             overview  popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...   21.946943
# 1  When siblings Judy and Peter discover an encha...   17.015539
# ...

# %%
movies.shape
# Out:
# (45443, 30)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45443 entries, 0 to 45442
# Data columns (total 30 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   adult                                45443 non-null  bool
#  1   budget                               45443 non-null  int64
#  2   homepage                             45443 non-null  object
#  3   id                                   45443 non-null  int64
#  4   imdb_id                              45443 non-null  object
#  5   original_language                    45443 non-null  object
#  6   original_title                       45443 non-null  object
#  7   overview                             45443 non-null  object
#  8   popularity                           45443 non-null  float64
#  9   poster_path                          45443 non-null  object
#  10  production_companies                 45443 non-null  object
# ...

# %%
# Check Missing Values
movies.isnull().sum()
# Out:
# adult                                      0
# budget                                     0
# homepage                                   0
# id                                         0
# imdb_id                                    0
# original_language                          0
# original_title                             0
# overview                                   0
# popularity                                 0
# poster_path                                0
# production_companies                       0
# release_date                               0
# revenue                                    0
# runtime                                    0
# status                                     0
# tagline                                    0
# title                                      0
# video                                      0
# vote_average                               0
# vote_count                                 0
# name_belongs_to_collection             40954
# ...

# %% [markdown]
# #### adult

# %%
movies['adult']
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 45438    False
# 45439    False
# 45440    False
# 45441    False
# 45442    False
# Name: adult, Length: 45443, dtype: bool

# %%
movies['adult'].describe()
# Out:
# count     45443
# unique        2
# top       False
# freq      45434
# Name: adult, dtype: object

# %%
movies['adult'].unique()
# Out:
# array([False,  True])

# %%
labels = ['False', 'True']
sns.countplot(x=movies['adult'], label=labels)
plt.legend()
plt.show()

# %%
labels = ['False','True']
plt.pie(movies['adult'].value_counts().values, labels=labels, autopct='%1.2f%%')
plt.show()

# %%
movies.drop(columns=['adult'], inplace=True)
movies.shape
# Out:
# (45443, 29)

# %% [markdown]
# ### Conclusion
# According to the analysis, we see that the adult feature of all the movies (almost 99.98%) is False . Therefore, this feature does not give us much useful information about the dataset

# %% [markdown]
# ### budget

# %%
movies['budget']
# Out:
# 0        30000000
# 1        65000000
# 2               0
# 3        16000000
# 4               0
#            ...
# 45438           0
# 45439           0
# 45440           0
# 45441           0
# 45442           0
# Name: budget, Length: 45443, dtype: int64

# %%
movies['budget'].describe()
# Out:
# count    4.544300e+04
# mean     4.226417e+06
# std      1.742775e+07
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      3.800000e+08
# Name: budget, dtype: float64

# %%
sns.histplot(movies['budget'])
plt.show()

# %%
# convert to million dollors
movies['budget'] = movies['budget'] * 1e-6
movies['budget']
# Out:
# 0        30.0
# 1        65.0
# 2         0.0
# 3        16.0
# 4         0.0
#          ...
# 45438     0.0
# 45439     0.0
# 45440     0.0
# 45441     0.0
# 45442     0.0
# Name: budget, Length: 45443, dtype: float64

# %% [markdown]
# ### Conclusion
# According to the describe and also the histogram, we see that the amount of budget for most of the films is zero.

# %% [markdown]
# ### homepage

# %%
movies['homepage']
# Out:
# 0        http://toystory.disney.com/toy-story
# 1                                        NANE
# 2                                        NANE
# 3                                        NANE
# 4                                        NANE
#                          ...
# 45438    http://www.imdb.com/title/tt6209470/
# 45439                                    NANE
# 45440                                    NANE
# 45441                                    NANE
# 45442                                    NANE
# Name: homepage, Length: 45443, dtype: object

# %%
for i in range(movies.shape[0]):
    if movies.loc[i, 'homepage'] == 'NANE':
        movies.loc[i, 'homepage'] = np.nan
movies['homepage']
# Out:
# 0        http://toystory.disney.com/toy-story
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#                          ...
# 45438    http://www.imdb.com/title/tt6209470/
# 45439                                     NaN
# 45440                                     NaN
# 45441                                     NaN
# 45442                                     NaN
# Name: homepage, Length: 45443, dtype: object

# %%
movies['homepage'].isna().sum()
# Out:
# 37667

# %%
movies['homepage'].isna().sum()/len(movies['homepage']) * 100
# Out:
# 82.88845366723147

# %%
movies.drop(columns=['homepage'], inplace=True)
movies.shape
# Out:
# (45443, 28)

# %% [markdown]
# ### Conclusion
# According to the analysis, we see that the homepage feature of almost 83% of movies is NaN . Therefore, this feature does not give us much useful information about the dataset

# %% [markdown]
# ### original language

# %%
movies['original_language']
# Out:
# 0        en
# 1        en
# 2        en
# 3        en
# 4        en
#          ..
# 45438    fa
# 45439    tl
# 45440    en
# 45441    en
# 45442    en
# Name: original_language, Length: 45443, dtype: object

# %%
movies['original_language'].describe()
# Out:
# count     45443
# unique       90
# top          en
# freq      32257
# Name: original_language, dtype: object

# %%
plt.figure(figsize=(20, 10))
sns.countplot(x=movies['original_language'])
plt.xticks(rotation=90)
plt.show()

# %%
original_lan = movies['original_language'].value_counts()
original_lan = np.array([original_lan['en'], original_lan['fr'], original_lan.sum() - original_lan['en'] - original_lan['fr']])
plt.pie(original_lan, labels=['en', 'fr', 'other'], autopct='%1.2f%%')
plt.show()

# %% [markdown]
# ### Conclusion
# According to the analysis, we see that the original_language feature of almost 71 of movies is en.

# %% [markdown]
# ### original_title

# %%
movies['original_title']
# Out:
# 0                          Toy Story
# 1                            Jumanji
# 2                   Grumpier Old Men
# 3                  Waiting to Exhale
# 4        Father of the Bride Part II
#                     ...
# 45438                        رگ خواب
# 45439            Siglo ng Pagluluwal
# 45440                       Betrayal
# 45441            Satana likuyushchiy
# 45442                       Queerama
# Name: original_title, Length: 45443, dtype: object

# %%
movies['original_title'].describe()
# Out:
# count                   45443
# unique                  43369
# top       Alice in Wonderland
# freq                        8
# Name: original_title, dtype: object

# %% [markdown]
# ### overview

# %%
movies['overview']
# Out:
# 0        Led by Woody, Andy's toys live happily in his ...
# 1        When siblings Judy and Peter discover an encha...
# 2        A family wedding reignites the ancient feud be...
# 3        Cheated on, mistreated and stepped on, the wom...
# 4        Just when George Banks has recovered from his ...
#                                ...
# 45438          Rising and falling between a man and woman.
# 45439    An artist struggles to finish his work while a...
# 45440    When one of her hits goes wrong, a professiona...
# 45441    In a small town live two brothers, one a minis...
# 45442    50 years after decriminalisation of homosexual...
# Name: overview, Length: 45443, dtype: object

# %%
for i in range(movies.shape[0]):
    if movies.loc[i, 'overview'] == 'NANE':
        movies.loc[i, 'overview'] = np.nan
movies['overview']
# Out:
# 0        Led by Woody, Andy's toys live happily in his ...
# 1        When siblings Judy and Peter discover an encha...
# 2        A family wedding reignites the ancient feud be...
# 3        Cheated on, mistreated and stepped on, the wom...
# 4        Just when George Banks has recovered from his ...
#                                ...
# 45438          Rising and falling between a man and woman.
# 45439    An artist struggles to finish his work while a...
# 45440    When one of her hits goes wrong, a professiona...
# 45441    In a small town live two brothers, one a minis...
# 45442    50 years after decriminalisation of homosexual...
# Name: overview, Length: 45443, dtype: object

# %%
movies['overview'].describe()
# Out:
# count                  44489
# unique                 44303
# top       No overview found.
# freq                     133
# Name: overview, dtype: object

# %%
movies[movies['overview'] == 'No overview found.']
# Out:
#        budget      id    imdb_id original_language           original_title  \
# 104       0.0   11907  tt0110251                de        Keiner liebt mich
# 800       0.0   12632  tt0110246                de            Kaspar Hauser
# 972       0.0   25739  tt0083587                en                L'associé
# 1612      1.0   29938  tt0112318                en             Alien Escape
# 2229      0.0    8336  tt0120767                en            The Naked Man
# ...       ...     ...        ...               ...                      ...
# 44585     0.0  144430  tt0188555                en   Ded Moroz i seriy volk
# 45229     0.0   28469  tt0273646                de            Der Herr Karl
# 45249     0.0   89606  tt0156602                en     Hemo The Magnificent
# 45269     0.0   31856  tt0172577                en             Hydrozagadka
# 45410     0.0    5589  tt0232750                cs  Šíleně smutná princezna
#
# ...

# %%
# %pip install wordcloud
# Out:
# ...
# WARNING: You are using pip version 21.3.1; however, version 23.1.2 is available.
# You should consider upgrading via the '/usr/local/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import wordcloud
movies['overview'] = movies['overview'].fillna('')
plt.figure(figsize=(20,20))
plt.title('The Most Common Word in Movie Overviews\n', fontsize=30, weight=600, color='#333d29')
wc = wordcloud.WordCloud(max_words=1000, min_font_size=10,
                height=800,width=1600,background_color="white").generate(' '.join(movies['overview']))

plt.imshow(wc)

# %% [markdown]
# ### Conclusion
# According to the word cloud plot, we see the most common word in Movie Overviews.

# %%
movies.columns
# Out:
# Index(['budget', 'id', 'imdb_id', 'original_language', 'original_title',
#        'overview', 'popularity', 'poster_path', 'production_companies',
#        'release_date', 'revenue', 'runtime', 'status', 'tagline', 'title',
#        'video', 'vote_average', 'vote_count', 'name_belongs_to_collection',
#        'id_belongs_to_collection', 'poster_path_belongs_to_collection',
#        'backdrop_path_belongs_to_collection', 'name_genres', 'id_genres',
#        'name_production_countries', 'iso_3166_1_production_companies',
#        'name_production_companies', 'id_production_companies'],
#       dtype='object')

# %%
movies = movies.rename(columns={'iso_3166_1_production_companies': 'iso_3166_1_production_countries'})
movies.columns
# Out:
# Index(['budget', 'id', 'imdb_id', 'original_language', 'original_title',
#        'overview', 'popularity', 'poster_path', 'production_companies',
#        'release_date', 'revenue', 'runtime', 'status', 'tagline', 'title',
#        'video', 'vote_average', 'vote_count', 'name_belongs_to_collection',
#        'id_belongs_to_collection', 'poster_path_belongs_to_collection',
#        'backdrop_path_belongs_to_collection', 'name_genres', 'id_genres',
#        'name_production_countries', 'iso_3166_1_production_countries',
#        'name_production_companies', 'id_production_companies'],
#       dtype='object')

# %%
movies.drop(columns=['production_companies'], inplace=True)
movies.shape
# Out:
# (45443, 27)

# %% [markdown]
# ### release_date

# %%
movies['release_date']
# Out:
# 0        1995-10-30
# 1        1995-12-15
# 2        1995-12-22
# 3        1995-12-22
# 4        1995-02-10
#             ...
# 45438          NANE
# 45439    2011-11-17
# 45440    2003-08-01
# 45441    1917-10-21
# 45442    2017-06-09
# Name: release_date, Length: 45443, dtype: object

# %%
for i in range(movies.shape[0]):
    if movies.loc[i, 'release_date'] == 'NANE':
        movies.loc[i, 'release_date'] = np.nan
movies['release_date']
# Out:
# 0        1995-10-30
# 1        1995-12-15
# 2        1995-12-22
# 3        1995-12-22
# 4        1995-02-10
#             ...
# 45438           NaN
# 45439    2011-11-17
# 45440    2003-08-01
# 45441    1917-10-21
# 45442    2017-06-09
# Name: release_date, Length: 45443, dtype: object

# %%
movies['release_date'] = pd.to_datetime(movies['release_date'])
movies['release_date'].describe()
# Out:
# /var/folders/9y/vw5physn1xj4wpb41wh0q6gh0000gn/T/ipykernel_11905/99230016.py:2: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   movies['release_date'].describe()
# count                   45359
# unique                  17333
# top       2008-01-01 00:00:00
# freq                      136
# first     1874-12-09 00:00:00
# last      2020-12-16 00:00:00
# Name: release_date, dtype: object

# %%
sns.displot(data=movies, x='release_date', kind='hist', kde=True, line_kws={'lw': 3}, aspect=3)
plt.title('Total Released Movie by Date', fontsize=18, weight=600)
plt.show()

# %% [markdown]
# ### Conclusion
# Started from 1930, movies industry had grown significantly from 50 years ago. A drop in total released movies around 2020 is because the dataset only contains a few data in those years

# %%
movies['budget'] = movies['budget'].astype('float64')
movies['popularity'] = movies['popularity'].astype('float64')

# %% [markdown]
# ### revenue

# %%
movies['revenue']
# Out:
# 0        373554033.0
# 1        262797249.0
# 2                0.0
# 3         81452156.0
# 4         76578911.0
#             ...
# 45438            0.0
# 45439            0.0
# 45440            0.0
# 45441            0.0
# 45442            0.0
# Name: revenue, Length: 45443, dtype: float64

# %%
movies['revenue'].describe()
# Out:
# count    4.544300e+04
# mean     1.121350e+07
# std      6.434392e+07
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      2.787965e+09
# Name: revenue, dtype: float64

# %%
movies['revenue'] = movies['revenue'] * 1e-6

# %%
movies_plot = movies[(movies['budget'] != 0) & (movies['revenue'] != 0)]

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 4))

plt.suptitle('The Influence of Budget and Revenue\non Popularity of Movies', fontsize=18)
for i, col in enumerate(['budget', 'revenue']):
    sns.regplot(data=movies_plot, x=col, y='popularity',
                scatter_kws={"alpha": 0.6}, line_kws={"color": "red"}, ax=axes[i])

plt.tight_layout()

# %%
ax = sns.jointplot(data=movies_plot, x='budget', y='revenue',
                   marker="*", s=100, marginal_kws=dict(bins=20, fill=False))
ax.fig.suptitle('Budget vs Revenue', fontsize=18)
ax.ax_joint.set_xlim(0, 1e3)
ax.ax_joint.set_ylim(0, 3e3)
ax.ax_joint.axline((1000,1000), slope=1, color='red')

# %% [markdown]
# ### Conclusion
# * Budget and Revenue just slighly influence the popularity of the movies.
# * Most of the movies lay on top of the yellow line, indicate that those movies make a profit.

# %% [markdown]
# ### runtime

# %%
movies['runtime']
# Out:
# 0         81.0
# 1        104.0
# 2        101.0
# 3        127.0
# 4        106.0
#          ...
# 45438     90.0
# 45439    360.0
# 45440     90.0
# 45441     87.0
# 45442     75.0
# Name: runtime, Length: 45443, dtype: object

# %%
for i in range(movies.shape[0]):
    if movies.loc[i, 'runtime'] == 'NANE':
        movies.loc[i, 'runtime'] = np.nan
movies['runtime']
# Out:
# 0         81.0
# 1        104.0
# 2        101.0
# 3        127.0
# 4        106.0
#          ...
# 45438     90.0
# 45439    360.0
# 45440     90.0
# 45441     87.0
# 45442     75.0
# Name: runtime, Length: 45443, dtype: object

# %%
movies['runtime'] = movies['runtime'].astype('float64')

# %%
movies['runtime'] = movies['runtime'].fillna(movies[movies['runtime'] != np.nan]['runtime'].mean())
movies['runtime'].describe()
# Out:
# count    45443.000000
# mean        94.126234
# std         38.303688
# min          0.000000
# 25%         85.000000
# 50%         95.000000
# 75%        107.000000
# max       1256.000000
# Name: runtime, dtype: float64

# %%
sns.displot(data=movies, x='runtime', kind='hist', kde=True, line_kws={'lw': 3}, aspect=3)
plt.title('Runtime of Movie', fontsize=18, weight=600)
plt.show()

# %%
sns.regplot(data=movies, x='runtime', y='popularity',
            scatter_kws={"alpha": 0.6}, line_kws={"color": "red"})

plt.tight_layout()

# %%
sns.regplot(data=movies, x='runtime', y='budget',
            scatter_kws={"alpha": 0.6}, line_kws={"color": "red"})

plt.tight_layout()

# %%
sns.regplot(data=movies, x='runtime', y='revenue',
            scatter_kws={"alpha": 0.6}, line_kws={"color": "red"})

plt.tight_layout()

# %% [markdown]
# ### status

# %%
movies['status']
# Out:
# 0        Released
# 1        Released
# 2        Released
# 3        Released
# 4        Released
#            ...
# 45438    Released
# 45439    Released
# 45440    Released
# 45441    Released
# 45442    Released
# Name: status, Length: 45443, dtype: object

# %%
movies['status'].describe()
# Out:
# count        45443
# unique           7
# top       Released
# freq         44998
# Name: status, dtype: object

# %%
movies['status'].unique()
# Out:
# array(['Released', 'NANE', 'Rumored', 'Post Production', 'In Production',
#        'Planned', 'Canceled'], dtype=object)

# %%
for i in range(movies.shape[0]):
    if movies.loc[i, 'status'] == 'NANE':
        movies.loc[i, 'status'] = np.nan
movies['status']
# Out:
# 0        Released
# 1        Released
# 2        Released
# 3        Released
# 4        Released
#            ...
# 45438    Released
# 45439    Released
# 45440    Released
# 45441    Released
# 45442    Released
# Name: status, Length: 45443, dtype: object

# %%
unique_status = movies['status'].unique()
unique_status
# Out:
# array(['Released', nan, 'Rumored', 'Post Production', 'In Production',
#        'Planned', 'Canceled'], dtype=object)

# %%
sns.countplot(x=movies['status'], label=np.delete(movies['status'].unique(),1))
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %%
plt.pie(movies['status'].value_counts().values, labels=np.delete(movies['status'].unique(),1), autopct='%1.2f%%')
plt.show()

# %% [markdown]
# ### Conclusion
# According to the plots, we found that status of almost 99.20% of movies is Released.

# %%
movies.columns
# Out:
# Index(['budget', 'id', 'imdb_id', 'original_language', 'original_title',
#        'overview', 'popularity', 'poster_path', 'release_date', 'revenue',
#        'runtime', 'status', 'tagline', 'title', 'video', 'vote_average',
#        'vote_count', 'name_belongs_to_collection', 'id_belongs_to_collection',
#        'poster_path_belongs_to_collection',
#        'backdrop_path_belongs_to_collection', 'name_genres', 'id_genres',
#        'name_production_countries', 'iso_3166_1_production_countries',
#        'name_production_companies', 'id_production_companies'],
#       dtype='object')

# %%
movies['video']
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 45438    False
# 45439    False
# 45440    False
# 45441    False
# 45442    False
# Name: video, Length: 45443, dtype: bool

# %%
movies['video'].describe()
# Out:
# count     45443
# unique        2
# top       False
# freq      45350
# Name: video, dtype: object

# %%
movies['video'].unique()
# Out:
# array([False,  True])

# %%
movies.drop(columns=['video'], inplace=True)

# %% [markdown]
# ### vote_average

# %%
movies['vote_average']
# Out:
# 0        7.7
# 1        6.9
# 2        6.5
# 3        6.1
# 4        5.7
#         ...
# 45438    4.0
# 45439    9.0
# 45440    3.8
# 45441    0.0
# 45442    0.0
# Name: vote_average, Length: 45443, dtype: float64

# %%
movies['vote_average'].describe()
# Out:
# count    45443.000000
# mean         5.618311
# std          1.924092
# min          0.000000
# 25%          5.000000
# 50%          6.000000
# 75%          6.800000
# max         10.000000
# Name: vote_average, dtype: float64

# %%
sns.regplot(data=movies, x='vote_average', y='popularity',
            scatter_kws={"alpha": 0.6}, line_kws={"color": "red"})

plt.tight_layout()

# %%
sns.regplot(data=movies, x='vote_average', y='budget',
            scatter_kws={"alpha": 0.6}, line_kws={"color": "red"})

plt.tight_layout()

# %%
sns.regplot(data=movies, x='vote_average', y='revenue',
            scatter_kws={"alpha": 0.6}, line_kws={"color": "red"})

plt.tight_layout()

# %%
sns.regplot(data=movies, x='vote_average', y='runtime',
            scatter_kws={"alpha": 0.6}, line_kws={"color": "red"})

plt.tight_layout()

# %% [markdown]
# ### vote_count

# %%
movies['vote_count']
# Out:
# 0        5415.0
# 1        2413.0
# 2          92.0
# 3          34.0
# 4         173.0
#           ...
# 45438       1.0
# 45439       3.0
# 45440       6.0
# 45441       0.0
# 45442       0.0
# Name: vote_count, Length: 45443, dtype: float64

# %%
movies['vote_count'].describe()
# Out:
# count    45443.000000
# mean       109.922210
# std        491.398368
# min          0.000000
# 25%          3.000000
# 50%         10.000000
# 75%         34.000000
# max      14075.000000
# Name: vote_count, dtype: float64

# %%
sns.regplot(data=movies, x='vote_count', y='popularity',
            scatter_kws={"alpha": 0.6}, line_kws={"color": "red"})

plt.tight_layout()

# %%
sns.regplot(data=movies, x='vote_count', y='budget',
            scatter_kws={"alpha": 0.6}, line_kws={"color": "red"})

plt.tight_layout()

# %%
sns.regplot(data=movies, x='vote_count', y='revenue',
            scatter_kws={"alpha": 0.6}, line_kws={"color": "red"})

plt.tight_layout()

# %%
sns.regplot(data=movies, x='vote_count', y='runtime',
            scatter_kws={"alpha": 0.6}, line_kws={"color": "red"})

plt.tight_layout()

# %%
def show_pairplot(data):
    sns.pairplot(movies, vars=data, diag_kind='kde')

show_pairplot(['budget', 'revenue', 'runtime', 'vote_average', 'vote_count', 'popularity'])

# %% [markdown]
# ### Conclusion
# This pairplot shows the relationship between the following features

# %% [markdown]
# ### belongs_to_collection

# %%
movies['name_belongs_to_collection']
# Out:
# 0                  Toy Story Collection
# 1                                   NaN
# 2             Grumpy Old Men Collection
# 3                                   NaN
# 4        Father of the Bride Collection
#                       ...
# 45438                               NaN
# 45439                               NaN
# 45440                               NaN
# 45441                               NaN
# 45442                               NaN
# Name: name_belongs_to_collection, Length: 45443, dtype: object

# %%
movies['name_belongs_to_collection'].isna().sum()
# Out:
# 40954

# %%
movies['id_belongs_to_collection'].isna().sum()
# Out:
# 40954

# %%
movies['poster_path_belongs_to_collection'].isna().sum()
# Out:
# 41497

# %%
movies['backdrop_path_belongs_to_collection'].isna().sum()
# Out:
# 42181

# %%
# drop all features of belong to collection beacase they have many missing values
movies.drop(columns=['name_belongs_to_collection', 'id_belongs_to_collection', 'poster_path_belongs_to_collection', 'backdrop_path_belongs_to_collection'], inplace=True)
movies.shape
# Out:
# (45443, 22)

# %% [markdown]
# ### genres

# %%
movies['name_genres']
# Out:
# 0         Animation, Comedy, Family
# 1        Adventure, Fantasy, Family
# 2                   Romance, Comedy
# 3            Comedy, Drama, Romance
# 4                            Comedy
#                     ...
# 45438                 Drama, Family
# 45439                         Drama
# 45440       Action, Drama, Thriller
# 45441                           NaN
# 45442                           NaN
# Name: name_genres, Length: 45443, dtype: object

# %%
movies['name_genres'].isna().sum()
# Out:
# 2442

# %%
movies['name_genres'].describe()
# Out:
# count     43001
# unique     4064
# top       Drama
# freq       4999
# Name: name_genres, dtype: object

# %%
def is_float(string):
    try:
        float(string)
        return True
    except ValueError:
        return False

genres_set = set()
def find_unique(genres_str):
    if not is_float(genres_str):
        string_list = genres_str.split(', ')
        for string in string_list:
            genres_set.add(string)

# %%
movies['name_genres'].apply(find_unique)
print('Number Of Unique genres:', len(genres_set))
# Out:
# Number Of Unique genres: 20

# %%
genres_dict = {}

for genre in genres_set:
    genres_dict[genre] = 0

print(genres_dict)
# Out:
# {'Horror': 0, 'Documentary': 0, 'History': 0, 'Thriller': 0, 'War': 0, 'Romance': 0, 'Drama': 0, 'Science Fiction': 0, 'Action': 0, 'Comedy': 0, 'Fantasy': 0, 'Family': 0, 'Western': 0, 'Crime': 0, 'Mystery': 0, 'Music': 0, 'TV Movie': 0, 'Animation': 0, 'Adventure': 0, 'Foreign': 0}

# %%
def count(genres_str):
    if not is_float(genres_str):
        string_list = genres_str.split(', ')
        for string in string_list:
            genres_dict[string] += 1

# %%
movies['name_genres'].apply(count)
max_key = max(genres_dict, key=lambda k: genres_dict[k])
print('The most used genre', '\"', max_key, '\"', ':',genres_dict.get(max_key))
min_key = min(genres_dict, key=lambda k: genres_dict[k])
print('The least used genre', '\"',min_key, '\"', ':',genres_dict.get(min_key))
# Out:
# The most used genre " Drama " : 20252
# The least used genre " TV Movie " : 766

# %%
genres = pd.DataFrame(genres_dict.items(), columns=['Name', 'Number'])
plt.figure(figsize=(15, 10))
sns.barplot(x=genres['Name'], y=genres['Number'])
plt.xticks(rotation=90)
plt.show()

# %%
movies.columns
# Out:
# Index(['budget', 'id', 'imdb_id', 'original_language', 'original_title',
#        'overview', 'popularity', 'poster_path', 'release_date', 'revenue',
#        'runtime', 'status', 'tagline', 'title', 'vote_average', 'vote_count',
#        'name_genres', 'id_genres', 'name_production_countries',
#        'iso_3166_1_production_countries', 'name_production_companies',
#        'id_production_companies'],
#       dtype='object')

# %% [markdown]
# ### production countries

# %%
movies['name_production_countries']
# Out:
# 0        United States of America
# 1        United States of America
# 2        United States of America
# 3        United States of America
# 4        United States of America
#                    ...
# 45438                        Iran
# 45439                 Philippines
# 45440    United States of America
# 45441                      Russia
# 45442              United Kingdom
# Name: name_production_countries, Length: 45443, dtype: object

# %%
movies['name_production_countries'].isna().sum()
# Out:
# 6279

# %%
movies['name_production_countries'].describe()
# Out:
# count                        39164
# unique                        2389
# top       United States of America
# freq                         17847
# Name: name_production_countries, dtype: object

# %%
countries_set = set()
def find_unique(countries_str):
    if not is_float(countries_str):
        string_list = countries_str.split(', ')
        for string in string_list:
            countries_set.add(string)

# %%
movies['name_production_countries'].apply(find_unique)
print('Number Of Unique countries:', len(countries_set))
# Out:
# Number Of Unique countries: 160

# %%
countries_dict = {}

for country in countries_set:
    countries_dict[country] = 0

print(countries_dict)

def count(countries_str):
    if not is_float(countries_str):
        string_list = countries_str.split(', ')
        for string in string_list:
            countries_dict[string] += 1
# Out:
# {'Madagascar': 0, 'Lithuania': 0, 'Hungary': 0, 'Poland': 0, 'Australia': 0, 'Puerto Rico': 0, 'Kyrgyz Republic': 0, 'Azerbaijan': 0, 'Sri Lanka': 0, 'Mongolia': 0, 'Paraguay': 0, 'Macao': 0, 'Namibia': 0, 'Angola': 0, 'Bahamas': 0, 'Slovenia': 0, 'Iceland': 0, 'Portugal': 0, 'Saudi Arabia': 0, 'Bhutan': 0, 'Algeria': 0, 'Ghana': 0, 'Barbados': 0, 'Argentina': 0, 'United Arab Emirates': 0, 'Costa Rica': 0, 'Kuwait': 0, 'Colombia': 0, 'Jamaica': 0, 'Bulgaria': 0, 'Nicaragua': 0, 'East Germany': 0, 'Montenegro': 0, 'Romania': 0, 'Kazakhstan': 0, 'Antarctica': 0, 'Luxembourg': 0, 'Estonia': 0, 'Latvia': 0, 'Taiwan': 0, 'Netherlands': 0, 'Uruguay': 0, 'Italy': 0, 'Liberia': 0, 'Cyprus': 0, 'South Africa': 0, 'Japan': 0, 'Singapore': 0, 'Afghanistan': 0, 'Spain': 0, 'Belgium': 0, 'Soviet Union': 0, 'China': 0, 'Papua New Guinea': 0, 'Palestinian Territory': 0, 'Guinea': 0, 'Serbia': 0, 'Pakistan': 0, 'Burkina Faso': 0, 'Qatar': 0, 'Croatia': 0, 'Canada': 0, 'Albania': 0, 'Russia': 0, 'Leb
# ...

# %%
movies['name_production_countries'].apply(count)
max_key = max(countries_dict, key=lambda k: countries_dict[k])
print('The most used country', '\"', max_key, '\"', ':',countries_dict.get(max_key))
min_key = min(countries_dict, key=lambda k: countries_dict[k])
print('The least used country', '\"',min_key, '\"', ':',countries_dict.get(min_key))
# Out:
# The most used country " United States of America " : 21148
# The least used country " Madagascar " : 1

# %%
top_50 = pd.DataFrame(sorted(countries_dict.items(), key=lambda item: item[1], reverse=True)[:50], columns=['Name', 'Number'])
print('Top 50 of Country', top_50, sep='\n')
# Out:
# Top 50 of Country
#                         Name  Number
# 0   United States of America   21148
# 1             United Kingdom    4091
# 2                     France    3935
# 3                    Germany    2250
# 4                      Italy    2168
# 5                     Canada    1765
# 6                      Japan    1648
# 7                      Spain     964
# 8                     Russia     912
# 9                      India     827
# 10                 Hong Kong     596
# 11                    Sweden     586
# 12                 Australia     570
# 13               South Korea     494
# 14                   Belgium     446
# 15                   Denmark     384
# 16                   Finland     381
# 17               Netherlands     375
# 18                     China     372
# 19                    Mexico     328
# 20                    Poland     318
# 21                    Brazil     291
# 22                 Argentina     254
# 23               Switzerland     254
# ...

# %%
plt.figure(figsize=(15, 10))
sns.barplot(x=top_50['Name'], y=top_50['Number'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### production companies

# %%
movies['name_production_companies']
# Out:
# 0                                  Pixar Animation Studios
# 1        TriStar Pictures, Teitler Film, Interscope Com...
# 2                             Warner Bros., Lancaster Gate
# 3                   Twentieth Century Fox Film Corporation
# 4               Sandollar Productions, Touchstone Pictures
#                                ...
# 45438                                                  NaN
# 45439                                          Sine Olivia
# 45440                              American World Pictures
# 45441                                            Yermoliev
# 45442                                                  NaN
# Name: name_production_companies, Length: 45443, dtype: object

# %%
movies['name_production_companies'].isna().sum()
# Out:
# 11870

# %%
movies['name_production_companies'].describe()
# Out:
# count                         33573
# unique                        22670
# top       Metro-Goldwyn-Mayer (MGM)
# freq                            742
# Name: name_production_companies, dtype: object

# %%
companies_set = set()
def find_unique(companies_str):
    if not is_float(companies_str):
        string_list = companies_str.split(', ')
        for string in string_list:
            companies_set.add(string)

movies['name_production_companies'].apply(find_unique)
print('Number Of Unique companies:', len(companies_set))
# Out:
# Number Of Unique companies: 23565

# %%
companies_dict = {}

for company in companies_set:
    companies_dict[company] = 0

del companies_dict['']
print(companies_dict)

def count(companies_str):
    if not is_float(companies_str):
        string_list = companies_str.split(', ')
        for string in string_list:
            if string != '':
                companies_dict[string] += 1
# Out:
# {'Innovisions': 0, 'Culver Studios': 0, 'Toscana Audiovisual': 0, 'Senator Film Produktion': 0, 'Dead Sea Films': 0, 'Falcon International Productions': 0, 'Metakwon Filmworks': 0, 'Dimitri Dimitriadis Film': 0, 'Horipro': 0, 'The Shuman Company': 0, 'TeleImage': 0, 'Wayfare Entertainment': 0, 'France Télévision Distribution': 0, 'Poj Filmproduktion AB': 0, 'Nickelodeon Animation Studios': 0, 'Wag TV': 0, 'Huayi Brothers & Taihe Film Investment': 0, 'Hoche Productions': 0, 'Pop Art Film Factory': 0, 'Parva Cinematografica': 0, 'Légende des Siècles': 0, 'Atlantic Picture Company': 0, 'Centre Street': 0, 'Bord Scannan na hEireann / Irish Film Board': 0, 'Jeonwonsa Film Co.': 0, 'Alessandro Iacovoni Produzione Cinematografica': 0, 'Phoenician Films': 0, 'Dreambridge Films': 0, 'My Way Pictures': 0, '5060 Productions': 0, 'Sack Amusement Enterprises': 0, 'Easy Company': 0, 'Laffilmes': 0, 'See-Saw Films': 0, 'Lauron Pictures': 0, 'Eye Productions': 0, 'Relevant Film': 0, 'Christian Wagne
# ...

# %%
movies['name_production_companies'].apply(count)
max_key = max(companies_dict, key=lambda k: companies_dict[k])
print('The most used company', '\"', max_key, '\"', ':',companies_dict.get(max_key))
min_key = min(companies_dict, key=lambda k: companies_dict[k])
print('The least used company', '\"',min_key, '\"', ':',companies_dict.get(min_key))
# Out:
# The most used company " Warner Bros. " : 1250
# The least used company " Innovisions " : 1

# %%
top_50 = pd.DataFrame(sorted(companies_dict.items(), key=lambda item: item[1], reverse=True)[:50], columns=['Name', 'Number'])
print('Top 50 of Company', top_50, sep='\n')
# Out:
# Top 50 of Company
#                                            Name  Number
# 0                                  Warner Bros.    1250
# 1                     Metro-Goldwyn-Mayer (MGM)    1075
# 2                            Paramount Pictures    1003
# 3        Twentieth Century Fox Film Corporation     836
# 4                            Universal Pictures     830
# 5                 Columbia Pictures Corporation     450
# 6                                        Canal+     437
# 7                             Columbia Pictures     431
# 8                            RKO Radio Pictures     301
# 9                                United Artists     279
# 10                              New Line Cinema     277
# 11                         Walt Disney Pictures     263
# 12                                          The     228
# 13                          Touchstone Pictures     225
# 14                             TriStar Pictures     197
# ...

# %%
plt.figure(figsize=(15, 10))
sns.barplot(x=top_50['Name'], y=top_50['Number'])
plt.xticks(rotation=90)
plt.show()

# %%
movies['year'] = pd.to_datetime(movies['release_date'], errors='coerce').apply(lambda x: str(x).split('-')[0] if x != np.nan else np.nan)
movies['name_genres'] = movies['name_genres'].fillna('[]')
for i in range(movies.shape[0]):
    if movies.loc[i, 'tagline'] == 'NANE':
        movies.loc[i, 'tagline'] = ''
movies['tagline']
# Out:
# 0
# 1                Roll the dice and unleash the excitement!
# 2        Still Yelling. Still Fighting. Still Ready for...
# 3        Friends are the people who let you be yourself...
# 4        Just When His World Is Back To Normal... He's ...
#                                ...
# 45438           Rising and falling between a man and woman
# 45439
# 45440                               A deadly game of wits.
# 45441
# 45442
# Name: tagline, Length: 45443, dtype: object

# %%
movies.to_csv('../data/MoviesMetadata.csv', index=False)

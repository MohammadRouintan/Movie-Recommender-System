# %% [markdown]
# ## Keywords Dataset EDA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
keywords = pd.read_csv('data/NewKeywords.csv')
keywords.head()
# Out:
#       id                                      name_keywords  \
# 0    862  jealousy, toy, boy, friendship, friends, rival...
# 1   8844  board game, disappearance, based on children's...
# 2  15602  fishing, best friend, duringcreditsstinger, ol...
# 3  31357  based on novel, interracial relationship, sing...
# 4  11862  baby, midlife crisis, confidence, aging, daugh...
#
#                                          id_keywords
# 0  931, 4290, 5202, 6054, 9713, 9823, 165503, 170...
# 1         10090, 10941, 15101, 33467, 158086, 158091
# 2                        1495, 12392, 179431, 208510
# 3                    818, 10131, 14768, 15160, 33455
# 4  1009, 1599, 2246, 4995, 5600, 10707, 13149, 33...

# %%
# find unique key word
def is_float(string):
    try:
        float(string)
        return True
    except ValueError:
        return False

keywords_set = set()
def find_unique(keywords_str):
    if not is_float(keywords_str):
        string_list = keywords_str.split(', ')
        for string in string_list:
            keywords_set.add(string)

# %%
keywords['name_keywords'].apply(find_unique)
# Out:
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
#          ...
# 45427    None
# 45428    None
# 45429    None
# 45430    None
# 45431    None
# Name: name_keywords, Length: 45432, dtype: object

# %%
print('Number Of Unique keywords:', len(keywords_set))
# Out:
# Number Of Unique keywords: 19961

# %%
keywords_dict = {}

for keyword in keywords_set:
    keywords_dict[keyword] = 0

print(keywords_dict)
# Out:
# {'lost continent': 0, 'rooster teeth': 0, 'troll': 0, 'abusive father': 0, 'paranormal investigation': 0, 'brisbane queensland': 0, 'injustice': 0, 'munchies': 0, 'detention': 0, 'sicilian': 0, 'reunion': 0, 'suburban chicago': 0, 'customer': 0, 'cabaret': 0, 'wilson pickett': 0, 'birth': 0, 'bluff': 0, 'enemy': 0, 'rhine': 0, 'dance act': 0, 'season': 0, 'milk': 0, 'writing in blood': 0, 'photocopier': 0, 'dog attack': 0, 'hercule poirot': 0, 'tokyo japan': 0, 'beretta': 0, '1920s': 0, 'augmented reality glasses': 0, 'domestic violence': 0, 'girl gang': 0, 'alien invasion': 0, 'meaning of life': 0, 'biblical': 0, 'fictional game show': 0, 'northern england': 0, 'guide book': 0, 'fish': 0, 'cautery': 0, 'conservative': 0, 'verona italy': 0, 'warsaw uprising': 0, 'cell mate': 0, 'railroad detective': 0, 'tracking shot': 0, 'quarterback': 0, 'film director': 0, 'dystopic future': 0, 'extra credit assignment': 0, 'song and dance': 0, 'divorced parents': 0, 'beagle': 0, 'advertising executive': 0, 'prostate cancer': 0, 'beach': 0, 'stepmother': 0, 'arts and culture': 0, 'ancient ritual': 0, 'nhl': 0, 'money bag': 0, 'film in a film': 0, 'algonquin indian': 0, 'devout': 0, 'pirate captain': 0, 'woodpecker': 0, 'tv ratings': 0, 'prison break': 0, 'rocket ship battle': 0, 'subway train': 0, 'child murderer': 0, 'corporation': 0, 'lgbt family': 0, 'freezing': 0, 'marching band': 0, 'painter': 0, 'snorkel': 0, 'maths teacher': 0, 'waltzing matilda': 0, 'episode film': 0, 'local indians': 0, 'jfk assassination': 0, 'political unrest': 0, 'female villain': 0, 'aftercreditsstinger': 0, 'computer tape': 0, 'bouncer': 0, 'off season': 0, 'bribery': 0, 'guadeloupe': 0, 'daughter–in–law': 0, 'thief': 0, 'stripping': 0, 'female bully': 0, 'son': 0, 'liberal': 0, 'edgar wallace': 0, 'insurance agent': 0, 'outlaw music': 0, 'anthropologist': 0, 'east los angeles': 0, 'seer': 0, 'child molestation': 0, 'vaudeville': 0, 'stetson': 0, 'new year': 0, 'nickname': 0, 'russian cinema': 0, 'ruthlessness': 0, 'payroll': 0, 'latvia': 0, 'dancing scene': 0, 'nauczyciel': 0, 'raw materials': 0, 'sexual exploitation': 0, 'child sex trade': 0, 'demeanor course': 0, 'explorer': 0, 'skateboarding': 0, 'stunts': 0, 'guitar duel': 0, 'family holiday': 0, 'dark killer': 0, 'small talk': 0, 'alien possession': 0, 'olympics': 0, 'studio tour': 0, 'atm': 0, 'investment': 0, 'adirondack mountains': 0, 'tension': 0, 'medusa': 0, 'greenwich london': 0, 'shark': 0, 'gulf of mexico': 0, 'syringe': 0, 'cologne': 0, 'shaky camera': 0, 'school mate': 0, 'neil young': 0, 'sci-fi horror': 0, 'silo': 0, 'pluto': 0, 'american flag': 0, 'boxing promoter': 0, 'dwarf': 0, 'ancient world': 0, 'shootout on beach': 0, 'hayabusa': 0, 'lava': 0, 'child play': 0, 'coat': 0, 'wine drinking': 0, 'pistol': 0, 'computer program': 0, 'secret organization': 0, 'honey3': 0, 'heart attack': 0, 'aeroplane': 0, 'time traveler': 0, 'government conspiracy': 0, 'draft': 0, 'congo': 0, 'lung transplant\xa0': 0, 'flat tire': 0, 'hobby': 0, 'rag tag group': 0, 'faith': 0, 'exzess': 0, 'diamond mine': 0, 'sparta greece': 0, '\xa0lp recording': 0, 'motocross': 0, 'hayloft': 0, 'stich': 0, 'czech republic': 0, 'sociologist': 0, 'what if': 0, 'drunkard': 0, 'northern lights': 0, 'obnoxious': 0, 'life sentence': 0, 'retired': 0, 'urzeitmonster': 0, 'last chance': 0, 'musicians life': 0, 'arthouse': 0, 'church service': 0, 'lhasa': 0, 'driving while stoned': 0, 'endurance': 0, 'post office': 0, 'adrenaline junkie': 0, 'animal park': 0, 'middle east conflict': 0, 'political party': 0, 'ballet performance': 0, 'idiot': 0, 'immigration': 0, 'archbishop': 0, 'great white shark': 0, 'temporary insanity': 0, 'anti-asylum': 0, 'figure skating': 0, 'daywalker': 0, 'recruiting': 0, 'sister-in-law': 0, 'saber-toothed tiger': 0, 'film studio': 0, 'broken neck': 0, 'deputy sheriff': 0, 'non statutory female on male rape': 0, 'medical experiment': 0, 'burial ground': 0, 'compassion': 0, '\xa0armwrestling': 0, 'lunch break ...

# %%
def count(keywords_str):
    if not is_float(keywords_str):
        string_list = keywords_str.split(', ')
        for string in string_list:
            keywords_dict[string] += 1

# %%
keywords['name_keywords'].apply(count)
# Out:
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
#          ...
# 45427    None
# 45428    None
# 45429    None
# 45430    None
# 45431    None
# Name: name_keywords, Length: 45432, dtype: object

# %%
max_key = max(keywords_dict, key=lambda k: keywords_dict[k])
print('The most used keyword', '\"', max_key, '\"', ':',keywords_dict.get(max_key))
# Out:
# The most used keyword " woman director " : 3039

# %%
min_key = min(keywords_dict, key=lambda k: keywords_dict[k])
print('The least used keyword', '\"',min_key, '\"', ':',keywords_dict.get(min_key))
# Out:
# The least used keyword " lost continent " : 1

# %%
top_50 = pd.DataFrame(sorted(keywords_dict.items(), key=lambda item: item[1], reverse=True)[:50], columns=['Word', 'Number'])
print('Top 50 in the most used keyword', top_50, sep='\n')
# Out:
# Top 50 in the most used keyword
#                     Word  Number
# 0         woman director    3039
# 1       independent film    1914
# 2                 murder    1285
# 3         based on novel     822
# 4                musical     726
# 5                    sex     679
# 6               violence     647
# 7                 nudity     629
# 8                revenge     618
# 9              biography     613
# 10              suspense     581
# 11                  love     565
# 12         female nudity     555
# 13                 sport     535
# 14                police     451
# 15  duringcreditsstinger     440
# 16              teenager     434
# 17                sequel     432
# 18            friendship     404
# 19          world war ii     390
# 20                  drug     358
# 21       stand-up comedy     349
# 22                prison     348
# 23           high school     314
# 24          martial arts     310
# 25               suicide     306
# 26                  rape     304
# 27           silent film     304
# 28             film noir     302
# 29            kidnapping     300
# 30                family     290
# 31         serial killer     289
# 32               monster     279
# 33                 alien     277
# 34              dystopia     270
# 35                 paris     265
# 36              new york     265
# 37                 blood     264
# 38                 short     259
# 39                   gay     258
# 40              marriage     253
# 41             christmas     250
# 42                 death     243
# 43                  gore     242
# 44              gangster     241
# 45                zombie     240
# 46            small town     236
# 47             detective     233
# 48            prostitute     232
# 49        london england     232

# %%
bottom_50 = pd.DataFrame(sorted(keywords_dict.items(), key=lambda item: item[1])[:50], columns=['Word', 'Number'])
print('Bottom 50 in the most used keyword', bottom_50, sep='\n')
# Out:
# Bottom 50 in the most used keyword
#                          Word  Number
# 0              lost continent       1
# 1               rooster teeth       1
# 2         brisbane queensland       1
# 3                    munchies       1
# 4            suburban chicago       1
# 5              wilson pickett       1
# 6                   dance act       1
# 7            writing in blood       1
# 8                 photocopier       1
# 9              hercule poirot       1
# 10  augmented reality glasses       1
# 11                 guide book       1
# 12                    cautery       1
# 13         railroad detective       1
# 14              tracking shot       1
# 15    extra credit assignment       1
# 16            prostate cancer       1
# 17                        nhl       1
# 18             film in a film       1
# 19           algonquin indian       1
# 20                 woodpecker       1
# 21         rocket ship battle       1
# 22                lgbt family       1
# 23                    snorkel       1
# 24              maths teacher       1
# 25           waltzing matilda       1
# 26              local indians       1
# 27              computer tape       1
# 28                 off season       1
# 29                 guadeloupe       1
# 30               female bully       1
# 31              edgar wallace       1
# 32               outlaw music       1
# 33          child molestation       1
# 34                   nickname       1
# 35                    payroll       1
# 36                 nauczyciel       1
# 37              raw materials       1
# 38            demeanor course       1
# 39                guitar duel       1
# 40                dark killer       1
# 41                   olympics       1
# 42                studio tour       1
# 43                        atm       1
# 44       adirondack mountains       1
# 45           greenwich london       1
# 46                school mate       1
# 47                 neil young       1
# 48          shootout on beach       1
# 49                   hayabusa       1

# %%
plt.figure(figsize=(15, 10))
sns.barplot(x=top_50['Word'], y=top_50['Number'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Conclusion
# According to the analysis, we found that the number of unique keywords is equal to 19961. The most used word in these words is the word "woman director", which is used 3039 times.
#
# According to the barplot, we see top 50 of most used keywords

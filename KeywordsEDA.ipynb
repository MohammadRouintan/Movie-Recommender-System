# %% [markdown]
# ## Keywords Dataset EDA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
keywords = pd.read_csv('data/NewKeywords.csv')
keywords.head()
# Out:
#       id                                      name_keywords  \
# 0    862  jealousy, toy, boy, friendship, friends, rival...
# 1   8844  board game, disappearance, based on children's...
# 2  15602  fishing, best friend, duringcreditsstinger, ol...
# 3  31357  based on novel, interracial relationship, sing...
# 4  11862  baby, midlife crisis, confidence, aging, daugh...
#
#                                          id_keywords
# 0  931, 4290, 5202, 6054, 9713, 9823, 165503, 170...
# 1         10090, 10941, 15101, 33467, 158086, 158091
# 2                        1495, 12392, 179431, 208510
# 3                    818, 10131, 14768, 15160, 33455
# 4  1009, 1599, 2246, 4995, 5600, 10707, 13149, 33...

# %%
# find unique key word
def is_float(string):
    try:
        float(string)
        return True
    except ValueError:
        return False

keywords_set = set()
def find_unique(keywords_str):
    if not is_float(keywords_str):
        string_list = keywords_str.split(', ')
        for string in string_list:
            keywords_set.add(string)

# %%
keywords['name_keywords'].apply(find_unique)
# Out:
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
#          ...
# 45427    None
# 45428    None
# 45429    None
# 45430    None
# 45431    None
# Name: name_keywords, Length: 45432, dtype: object

# %%
print('Number Of Unique keywords:', len(keywords_set))
# Out:
# Number Of Unique keywords: 19961

# %%
keywords_dict = {}

for keyword in keywords_set:
    keywords_dict[keyword] = 0

print(keywords_dict)
# Out:
# {'easter bunny': 0, 'estranged daughter': 0, 'bell tower': 0, 'movie theatre': 0, 'diabolical ego': 0, 'deadly snake': 0, 'stronger villain': 0, 'perry mason': 0, 'oncologist': 0, 'chevrolet': 0, 'neurosis': 0, 'green dress': 0, 'the saint': 0, 'self righteousness': 0, 'schoolmates': 0, 'drive-in theatre': 0, 'garbage dump dwellers': 0, 'ice block': 0, 'unreliable narrator': 0, 'child prodigy': 0, 'petrol exploitation': 0, 'aviatrix': 0, 'fools': 0, 'rothschild': 0, 'tecno brego': 0, 'narcissist': 0, 'operation': 0, 'credit': 0, 'pixie': 0, 'massage': 0, 'bicycle taxi': 0, 'rats': 0, 'gravity': 0, 'mission to mars': 0, 'superhero': 0, 'chess tournament': 0, 'sepia color': 0, 'paris commune': 0, 'interracial couple': 0, 'long distance running': 0, 'the flemish cap': 0, 'totem': 0, 'fondling': 0, 'illegal matches': 0, 'opportunity': 0, 'stonehenge': 0, "driver's test": 0, 'doctor': 0, 'chain store magnate': 0, 'story': 0, 'altering history': 0, 'power company': 0, 'confusion': 0, 'star
# ...

# %%
def count(keywords_str):
    if not is_float(keywords_str):
        string_list = keywords_str.split(', ')
        for string in string_list:
            keywords_dict[string] += 1

# %%
keywords['name_keywords'].apply(count)
# Out:
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
#          ...
# 45427    None
# 45428    None
# 45429    None
# 45430    None
# 45431    None
# Name: name_keywords, Length: 45432, dtype: object

# %%
keywords_dict.values()
# Out:
# dict_values

# %%
max_key = max(keywords_dict, key=lambda k: keywords_dict[k])
print('The most used keyword', '\"', max_key, '\"', ':',keywords_dict.get(max_key))
# Out:
# The most used keyword " woman director " : 3039

# %%
min_key = min(keywords_dict, key=lambda k: keywords_dict[k])
print('The most used keyword', '\"',min_key, '\"', ':',keywords_dict.get(min_key))
# Out:
# The most used keyword " diabolical ego " : 1

# %%
top_50 = pd.DataFrame(sorted(keywords_dict.items(), key=lambda item: item[1], reverse=True)[:50], columns=['Word', 'Number'])
print('Top 50 in the most used keyword', top_50, sep='\n')
# Out:
# Top 50 in the most used keyword
#                     Word  Number
# 0         woman director    3039
# 1       independent film    1914
# 2                 murder    1285
# 3         based on novel     822
# 4                musical     726
# 5                    sex     679
# 6               violence     647
# 7                 nudity     629
# 8                revenge     618
# 9              biography     613
# 10              suspense     581
# 11                  love     565
# 12         female nudity     555
# 13                 sport     535
# 14                police     451
# 15  duringcreditsstinger     440
# 16              teenager     434
# 17                sequel     432
# 18            friendship     404
# 19          world war ii     390
# 20                  drug     358
# 21       stand-up comedy     349
# 22                prison     348
# 23           high school     314
# 24          martial arts     310
# 25               suicide     306
# ...

# %%
bottom_50 = pd.DataFrame(sorted(keywords_dict.items(), key=lambda item: item[1])[:50], columns=['Word', 'Number'])
print('Bottom 50 in the most used keyword', bottom_50, sep='\n')
# Out:
# Bottom 50 in the most used keyword
#                          Word  Number
# 0              diabolical ego       1
# 1            stronger villain       1
# 2                 green dress       1
# 3          self righteousness       1
# 4       garbage dump dwellers       1
# 5         petrol exploitation       1
# 6                       fools       1
# 7                  rothschild       1
# 8                 tecno brego       1
# 9                       pixie       1
# 10               bicycle taxi       1
# 11                       rats       1
# 12                sepia color       1
# 13              paris commune       1
# 14      long distance running       1
# 15            the flemish cap       1
# 16                      totem       1
# 17            illegal matches       1
# 18                opportunity       1
# 19                 stonehenge       1
# 20              driver's test       1
# 21        chain store magnate       1
# 22           altering history       1
# ...

# %%
plt.figure(figsize=(15, 10))
sns.barplot(x=top_50['Word'], y=top_50['Number'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Conclusion
# According to the analysis, we found that the number of unique keywords is equal to 19961. The most used word in these words is the word "woman director", which is used 3039 times.
#
# According to the barplot, we see top 50 of most used keywords

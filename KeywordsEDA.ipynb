# %% [markdown]
# ## Keywords Dataset EDA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
keywords = pd.read_csv('data/NewKeywords.csv')
keywords.head()
# Out:
#       id                                      name_keywords  \
# 0    862  jealousy, toy, boy, friendship, friends, rival...
# 1   8844  board game, disappearance, based on children's...
# 2  15602  fishing, best friend, duringcreditsstinger, ol...
# 3  31357  based on novel, interracial relationship, sing...
# 4  11862  baby, midlife crisis, confidence, aging, daugh...
#
#                                          id_keywords
# 0  931, 4290, 5202, 6054, 9713, 9823, 165503, 170...
# 1         10090, 10941, 15101, 33467, 158086, 158091
# 2                        1495, 12392, 179431, 208510
# 3                    818, 10131, 14768, 15160, 33455
# 4  1009, 1599, 2246, 4995, 5600, 10707, 13149, 33...

# %%
# find unique key word
def is_float(string):
    try:
        float(string)
        return True
    except ValueError:
        return False

keywords_set = set()
def find_unique(keywords_str):
    if not is_float(keywords_str):
        string_list = keywords_str.split(', ')
        for string in string_list:
            keywords_set.add(string)

# %%
keywords['name_keywords'].apply(find_unique)
# Out:
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
#          ...
# 45427    None
# 45428    None
# 45429    None
# 45430    None
# 45431    None
# Name: name_keywords, Length: 45432, dtype: object

# %%
print('Number Of Unique keywords:', len(keywords_set))
# Out:
# Number Of Unique keywords: 19961

# %%
keywords_dict = {}

for keyword in keywords_set:
    keywords_dict[keyword] = 0

print(keywords_dict)
# Out:
# {'beluga whale': 0, 'bag of money': 0, 'dying': 0, 'college intern': 0, 'strawberry': 0, 'concentration camp': 0, 'swamp thing': 0, 'glam metal': 0, 'enigma': 0, 'robotics club': 0, 'mullet': 0, 'marriage counselor': 0, 'texas': 0, 'security guard': 0, 'busker': 0, "child's point of view": 0, 'comradeship': 0, 'american girl': 0, 'israel': 0, 'hypothermia': 0, 'cyber terrorist': 0, 'cuban refugees': 0, 'vehicle combat': 0, 'epilogue': 0, 'race riot': 0, 'mpaa': 0, 'trilogy': 0, 'saving lives': 0, 'mouse': 0, 'ultimate': 0, 'disorder': 0, 'anthrax': 0, 'religious fanatic': 0, 'seven years war': 0, 'ancestor': 0, 'gambling': 0, 'submissive': 0, 'sushi': 0, 'blackboard': 0, 'interplanetary war': 0, 'american in the uk': 0, 'sheepdog': 0, 'statue': 0, 'law officer': 0, 'war dog': 0, 'southern usa': 0, 'invite': 0, 'ape': 0, 'poet': 0, 'polygraph': 0, 'genocide in indonesia': 0, 'motos': 0, 'dance teacher': 0, 'brussels': 0, 'mental hospital': 0, 'insomniac': 0, 'toy soldier': 0, 'socially awkward': 0, 'ntr25': 0, 'disintegration': 0, 'stage mother': 0, 'accepting death': 0, 'státní bezpečnost': 0, 'tennis': 0, 'weltkrieg': 0, 'haunted hotel': 0, 'rangoon burma': 0, 'insurance company': 0, 'institutionalization': 0, 'brigands': 0, 'still birth': 0, 'infiltration': 0, 'bad attitude': 0, 'little rascals': 0, 'indycar': 0, 'observational comedy': 0, 'cyclops': 0, 'manipulator': 0, 'monte carlo rally': 0, 'airline pilot': 0, 'killing spree': 0, 'old building': 0, 'toothache': 0, 'manicurist': 0, 'high seas': 0, 'algerian': 0, 'wall safe': 0, 'family disapproval': 0, 'oppression': 0, 'joe coffey': 0, 'bisexuality': 0, 'black white relations': 0, 'school principal': 0, 'beautiful': 0, 'bridesmaid': 0, 'moulin rouge': 0, 'nobility': 0, 'loss of energy': 0, 'bűnös utakon': 0, 'hick': 0, 'meltdown': 0, 'midwife': 0, 'swordplay': 0, 'tour': 0, 'policeman': 0, 'italy': 0, 'duet': 0, 'budweiser': 0, 'porto': 0, 'grave': 0, 'adultress': 0, 'diving suit': 0, 'pepper spray': 0, 'the flemish cap': 0, 'phantom zone': 0, 'hand on crotch': 0, 'hooded figure': 0, 'battle': 0, 'car dealing': 0, 'braggart': 0, 'told in flasblack': 0, 'meat market': 0, 'yellow fever': 0, 'cárcel': 0, 'singularity': 0, 'georgia': 0, 'pseudo documentary': 0, 'biological experiment': 0, 'crossfit': 0, 'munich treaty': 0, 'sentimental': 0, 'aerial photography': 0, 'gallery': 0, 'spider bite': 0, 'pātea': 0, 'decision': 0, 'chivalry': 0, 'adopted child': 0, 'tiny home': 0, 'it burns': 0, 'death of sister': 0, 'post-punk': 0, 'request': 0, 'new york art world': 0, 'nail gun': 0, 'victory': 0, 'chained to a wall': 0, 'bullet time': 0, 'frozen body': 0, 'puppy mill': 0, 'violent storm': 0, 'tout': 0, 'wanted man': 0, 'steak on black eye': 0, 'deputy head': 0, 'malnutrition': 0, 'post traumatic stress  disorder': 0, 'lover': 0, 'werewolf child': 0, 'shrimp': 0, 'cardinal': 0, 'swearing': 0, 'schoolhouse': 0, 'homicide detective': 0, 'bromance': 0, 'being followed': 0, 'flying': 0, 'accountant': 0, 'topless woman': 0, 'historic': 0, 'multiculturalism': 0, 'boundary violations': 0, 'spending money': 0, 'robber': 0, 'bath tub': 0, 'cinemascope': 0, 'feelbad': 0, 'comic strip': 0, 'gascon': 0, 'guardian angel': 0, 'animal research': 0, 'queer': 0, 'stuttering': 0, 'japanese occupation': 0, 'non conformity': 0, 'dreamer': 0, 'pentagon': 0, 'katanga conflict': 0, 'live comedy': 0, 'tripping and falling': 0, 'summer holiday': 0, 'teen drama': 0, 'puritan': 0, 'robot suits': 0, 'gang war': 0, 'solitary confinement': 0, 'jump from train': 0, 'bogotá': 0, 'cabin in the woods': 0, 'monster': 0, 'celibacy': 0, 'creek': 0, 'based on short story': 0, 'monty python': 0, 'swimwear': 0, 'the pirate bay': 0, 'gamera': 0, 'jedi': 0, 'people eater': 0, 'subway accident': 0, 'ailul al aswad': 0, 'loss of son': 0, 'cemetary': 0, 'alphabet': 0, 'molotow cocktail': 0, 'obedience': 0, 'diary': 0, 'death penalty': 0, 'burglary': 0, 'nepal': 0, 'fragmented': 0, 'brokerage': 0, 'lovers': 0, 'bugle': 0, 'roc ...

# %%
def count(keywords_str):
    if not is_float(keywords_str):
        string_list = keywords_str.split(', ')
        for string in string_list:
            keywords_dict[string] += 1

# %%
keywords['name_keywords'].apply(count)
# Out:
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
#          ...
# 45427    None
# 45428    None
# 45429    None
# 45430    None
# 45431    None
# Name: name_keywords, Length: 45432, dtype: object

# %%
max_key = max(keywords_dict, key=lambda k: keywords_dict[k])
print('The most used keyword', '\"', max_key, '\"', ':',keywords_dict.get(max_key))
# Out:
# The most used keyword " woman director " : 3039

# %%
min_key = min(keywords_dict, key=lambda k: keywords_dict[k])
print('The least used keyword', '\"',min_key, '\"', ':',keywords_dict.get(min_key))
# Out:
# The least used keyword " beluga whale " : 1

# %%
top_50 = pd.DataFrame(sorted(keywords_dict.items(), key=lambda item: item[1], reverse=True)[:50], columns=['Word', 'Number'])
print('Top 50 in the most used keyword', top_50, sep='\n')
# Out:
# Top 50 in the most used keyword
#                     Word  Number
# 0         woman director    3039
# 1       independent film    1914
# 2                 murder    1285
# 3         based on novel     822
# 4                musical     726
# 5                    sex     679
# 6               violence     647
# 7                 nudity     629
# 8                revenge     618
# 9              biography     613
# 10              suspense     581
# 11                  love     565
# 12         female nudity     555
# 13                 sport     535
# 14                police     451
# 15  duringcreditsstinger     440
# 16              teenager     434
# 17                sequel     432
# 18            friendship     404
# 19          world war ii     390
# 20                  drug     358
# 21       stand-up comedy     349
# 22                prison     348
# 23           high school     314
# 24          martial arts     310
# 25               suicide     306
# 26           silent film     304
# 27                  rape     304
# 28             film noir     302
# 29            kidnapping     300
# 30                family     290
# 31         serial killer     289
# 32               monster     279
# 33                 alien     277
# 34              dystopia     270
# 35              new york     265
# 36                 paris     265
# 37                 blood     264
# 38                 short     259
# 39                   gay     258
# 40              marriage     253
# 41             christmas     250
# 42                 death     243
# 43                  gore     242
# 44              gangster     241
# 45                zombie     240
# 46            small town     236
# 47             detective     233
# 48        london england     232
# 49            prostitute     232

# %%
bottom_50 = pd.DataFrame(sorted(keywords_dict.items(), key=lambda item: item[1])[:50], columns=['Word', 'Number'])
print('Bottom 50 in the most used keyword', bottom_50, sep='\n')
# Out:
# Bottom 50 in the most used keyword
#                      Word  Number
# 0            beluga whale       1
# 1          college intern       1
# 2              strawberry       1
# 3              glam metal       1
# 4           robotics club       1
# 5                  mullet       1
# 6      marriage counselor       1
# 7             comradeship       1
# 8           american girl       1
# 9         cyber terrorist       1
# 10         cuban refugees       1
# 11         vehicle combat       1
# 12               epilogue       1
# 13                   mpaa       1
# 14               ultimate       1
# 15                anthrax       1
# 16                  sushi       1
# 17               sheepdog       1
# 18                war dog       1
# 19                 invite       1
# 20  genocide in indonesia       1
# 21                  motos       1
# 22              insomniac       1
# 23            toy soldier       1
# 24       socially awkward       1
# 25                  ntr25       1
# 26           stage mother       1
# 27        accepting death       1
# 28      státní bezpečnost       1
# 29              weltkrieg       1
# 30          rangoon burma       1
# 31      insurance company       1
# 32   institutionalization       1
# 33            still birth       1
# 34           bad attitude       1
# 35         little rascals       1
# 36                indycar       1
# 37            manipulator       1
# 38           old building       1
# 39              toothache       1
# 40              high seas       1
# 41              wall safe       1
# 42             joe coffey       1
# 43         loss of energy       1
# 44           bűnös utakon       1
# 45               meltdown       1
# 46                   duet       1
# 47              budweiser       1
# 48                  porto       1
# 49              adultress       1

# %%
plt.figure(figsize=(15, 10))
sns.barplot(x=top_50['Word'], y=top_50['Number'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Conclusion
# According to the analysis, we found that the number of unique keywords is equal to 19961. The most used word in these words is the word "woman director", which is used 3039 times.
#
# According to the barplot, we see top 50 of most used keywords
